# %% [markdown]
# # Load results from TSEA/CSEA and make a simpler plot
#
# Update 210323 to sampling results
#
# Update 210629 to include height

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import networkx as nx
import pandas as pd
import random


# latex rendering of text in graphs
import matplotlib as mpl
mpl.rc('text', usetex = False)
mpl.rc('font', family = 'serif')

sns.set(font_scale=1.3)
from matplotlib import rcParams
rcParams['font.family'] = 'sans-serif'
rcParams['font.sans-serif'] = ['Arial']

sns.set_style('white')
sns.set_style("ticks", {"xtick.major.size": 15, "ytick.major.size": 15})
plt.rcParams['svg.fonttype'] = 'none'
import sys

% matplotlib inline

# for better labeling
import adjustText
# Out:
# UsageError: Line magic function `%` not found.

# %% [markdown]
# # Load BMI tissue specific results

# %%
DATADIR= '~/Data/rat/data/final/'# location of input datasets

# %%
# load tissue-specific results
tsea_df = pd.read_excel(DATADIR+'../tables/TSEA_rat_human_BMI_GIANT_sampling_210323.xlsx')
tsea_df = tsea_df[['Tissues and P-Values',0.05]]
tsea_df.columns=['Tissue','tsea_threshold_0.05']

p_split = tsea_df['tsea_threshold_0.05'].tolist()
p_list = [float(p.split(' ')[0]) for p in p_split]
FDR_list = [float(p.split(' ')[2]) for p in p_split]

tsea_df['p']=p_list
tsea_df['FDR']=FDR_list
tsea_df=tsea_df.sort_values('p')
tsea_df.index=tsea_df['Tissue']
tsea_df['pheno']='BMI'
tsea_df.head()
# Out:
#               Tissue      tsea_threshold_0.05             p           FDR  \
# Tissue
# Brain          Brain  1.247e-08 ( 3.117e-07 )  1.247000e-08  3.117000e-07
# Nerve          Nerve      0.0006537 ( 0.008 )  6.537000e-04  8.000000e-03
# Pancreas    Pancreas          0.009 ( 0.067 )  9.000000e-03  6.700000e-02
# Uterus        Uterus          0.011 ( 0.067 )  1.100000e-02  6.700000e-02
# Pituitary  Pituitary          0.021 ( 0.104 )  2.100000e-02  1.040000e-01
#
#           pheno
# Tissue
# Brain       BMI
# Nerve       BMI
# Pancreas    BMI
# Uterus      BMI
# Pituitary   BMI

# %%
tsea_height_df = pd.read_excel(DATADIR + '../tables/TSEA_rat_human_HEIGHT_GIANT_sampling_210323.xlsx')
tsea_height_df = tsea_height_df[['Tissues and P-Values',0.05]]
tsea_height_df.columns=['Tissue','tsea_threshold_0.05']


p_split = tsea_height_df['tsea_threshold_0.05'].tolist()
p_list = [float(p.split(' ')[0]) for p in p_split]
FDR_list = [float(p.split(' ')[2]) for p in p_split]

tsea_height_df['p']=p_list
tsea_height_df['FDR']=FDR_list
tsea_height_df=tsea_height_df.sort_values('p')
tsea_height_df.index=tsea_height_df['Tissue']
tsea_height_df['pheno']='height'
tsea_height_df.head()
# Out:
#                         Tissue tsea_threshold_0.05      p  FDR   pheno
# Tissue
# Blood Vessel      Blood Vessel       0.169 ( 1.0 )  0.169  1.0  height
# Blood                    Blood       0.241 ( 1.0 )  0.241  1.0  height
# Adipose Tissue  Adipose Tissue       0.531 ( 1.0 )  0.531  1.0  height
# Muscle                  Muscle       0.614 ( 1.0 )  0.614  1.0  height
# Fallopian Tube  Fallopian Tube        0.64 ( 1.0 )  0.640  1.0  height

# %%
tsea_height_df['FDR'].min()
# Out:
# 1.0

# %%
tsea_df = tsea_df.append(tsea_height_df)
tsea_df['-log10(FDR)']=-np.log10(tsea_df['FDR'])
tsea_df['-log10(p)']=-np.log10(tsea_df['p'])
tsea_df.head()
# Out:
#               Tissue      tsea_threshold_0.05             p           FDR  \
# Tissue
# Brain          Brain  1.247e-08 ( 3.117e-07 )  1.247000e-08  3.117000e-07
# Nerve          Nerve      0.0006537 ( 0.008 )  6.537000e-04  8.000000e-03
# Pancreas    Pancreas          0.009 ( 0.067 )  9.000000e-03  6.700000e-02
# Uterus        Uterus          0.011 ( 0.067 )  1.100000e-02  6.700000e-02
# Pituitary  Pituitary          0.021 ( 0.104 )  2.100000e-02  1.040000e-01
#
#           pheno  -log10(FDR)  -log10(p)
# Tissue
# Brain       BMI     6.506263   7.904134
# Nerve       BMI     2.096910   3.184622
# Pancreas    BMI     1.173925   2.045757
# Uterus      BMI     1.173925   1.958607
# Pituitary   BMI     0.982967   1.677781

# %%
tissues_plot = np.unique(tsea_df[tsea_df['p']<1].index.tolist())
print(len(tissues_plot))
# Out:
# 25

# %%
plt.figure(figsize=(6,4))
plot_temp = tsea_df.loc[tissues_plot]
plot_temp = plot_temp.sort_values('p')
# plt.bar(np.arange(len(tsea_df)),-np.log10(tsea_df['FDR'].tolist()))
sns.barplot(x='Tissue',y='-log10(p)',data=plot_temp.loc[plot_temp.pheno=="BMI"])
tmp=plt.xticks(rotation='vertical')
plt.ylabel('-log10(p)', fontsize=20)
plt.savefig('../manuscript/figures/figure3/tsea_rat_human_BMI_210629.png',dpi=300,bbox_inches='tight')
# plt.savefig('../manuscript/figures/figure3/tsea_rat_human_BMI_210212.svg')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_838102/3159435776.py in <module>
#       6 tmp=plt.xticks(rotation='vertical')
#       7 plt.ylabel('-log10(p)', fontsize=20)
# ----> 8 plt.savefig('../manuscript/figures/figure3/tsea_rat_human_BMI_210629.png',dpi=300,bbox_inches='tight')
#       9 # plt.savefig('../manuscript/figures/figure3/tsea_rat_human_BMI_210212.svg')
#
# ~/anaconda3/envs/netcoloc_R/lib/python3.9/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     964 def savefig(*args, **kwargs):
#     965     fig = gcf()
# --> 966     res = fig.savefig(*args, **kwargs)
#     967     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     968     return res
#
# ~/anaconda3/envs/netcoloc_R/lib/python3.9/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    3013                 patch.set_edgecolor('none')
#    3014
# -> 3015         self.canvas.print_figure(fname, **kwargs)
#    3016
#    3017         if transparent:
#
# ~/anaconda3/envs/netcoloc_R/lib/python3.9/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2253                 # force the figure dpi to 72), so we need to set it again here.
#    2254                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2255                     result = print_method(
#    2256                         filename,
#    2257                         facecolor=facecolor,
#
# ~/anaconda3/envs/netcoloc_R/lib/python3.9/site-packages/matplotlib/backend_bases.py in wrapper(*args, **kwargs)
#    1667             kwargs.pop(arg)
#    1668
# -> 1669         return func(*args, **kwargs)
#    1670
#    1671     return wrapper
#
# ~/anaconda3/envs/netcoloc_R/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     507         """
#     508         FigureCanvasAgg.draw(self)
# --> 509         mpl.image.imsave(
#     510             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#     511             dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# ~/anaconda3/envs/netcoloc_R/lib/python3.9/site-packages/matplotlib/image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1614         pil_kwargs.setdefault("format", format)
#    1615         pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1616         image.save(fname, **pil_kwargs)
#    1617
#    1618
#
# ~/anaconda3/envs/netcoloc_R/lib/python3.9/site-packages/PIL/Image.py in save(self, fp, format, **params)
#    2230                 fp = builtins.open(filename, "r+b")
#    2231             else:
# -> 2232                 fp = builtins.open(filename, "w+b")
#    2233
#    2234         try:
#
# FileNotFoundError: [Errno 2] No such file or directory: '../manuscript/figures/figure3/tsea_rat_human_BMI_210629.png'

# %%
tsea_df.loc[tissues_plot]
# Out:
#                         Tissue      tsea_threshold_0.05             p  \
# Tissue
# Adrenal Gland    Adrenal Gland          0.107 ( 0.334 )  1.070000e-01
# Adrenal Gland    Adrenal Gland            0.718 ( 1.0 )  7.180000e-01
# Blood                    Blood          0.912 ( 0.999 )  9.120000e-01
# Blood                    Blood            0.241 ( 1.0 )  2.410000e-01
# Blood Vessel      Blood Vessel          0.134 ( 0.357 )  1.340000e-01
# Blood Vessel      Blood Vessel            0.169 ( 1.0 )  1.690000e-01
# Brain                    Brain  1.247e-08 ( 3.117e-07 )  1.247000e-08
# Brain                    Brain            0.994 ( 1.0 )  9.940000e-01
# Colon                    Colon          0.043 ( 0.178 )  4.300000e-02
# Colon                    Colon            0.997 ( 1.0 )  9.970000e-01
# Fallopian Tube  Fallopian Tube           0.426 ( 0.76 )  4.260000e-01
# Fallopian Tube  Fallopian Tube             0.64 ( 1.0 )  6.400000e-01
# Muscle                  Muscle          0.058 ( 0.206 )  5.800000e-02
# Muscle                  Muscle            0.614 ( 1.0 )  6.140000e-01
# Nerve                    Nerve      0.0006537 ( 0.008 )  6.537000e-04
# Nerve                    Nerve            0.953 ( 1.0 )  9.530000e-01
# Pancreas              Pancreas          0.009 ( 0.067 )  9.000000e-03
# Pancreas              Pancreas            0.946 ( 1.0 )  9.460000e-01
# Pituitary            Pituitary          0.021 ( 0.104 )  2.100000e-02
# Pituitary            Pituitary             0.99 ( 1.0 )  9.900000e-01
# Prostate              Prostate          0.149 ( 0.357 )  1.490000e-01
# Prostate              Prostate             0.97 ( 1.0 )  9.700000e-01
# Skin                      Skin          0.391 ( 0.751 )  3.910000e-01
# Skin                      Skin            0.791 ( 1.0 )  7.910000e-01
# Thyroid                Thyroid            0.288 ( 0.6 )  2.880000e-01
# Thyroid                Thyroid            0.993 ( 1.0 )  9.930000e-01
# Uterus                  Uterus          0.011 ( 0.067 )  1.100000e-02
# Uterus                  Uterus            0.684 ( 1.0 )  6.840000e-01
# Vagina                  Vagina          0.157 ( 0.357 )  1.570000e-01
# Vagina                  Vagina            0.737 ( 1.0 )  7.370000e-01
#
#                          FDR   pheno  -log10(FDR)  -log10(p)
# Tissue
# Adrenal Gland   3.340000e-01     BMI     0.476254   0.970616
# Adrenal Gland   1.000000e+00  height    -0.000000   0.143876
# Blood           9.990000e-01     BMI     0.000435   0.040005
# Blood           1.000000e+00  height    -0.000000   0.617983
# Blood Vessel    3.570000e-01     BMI     0.447332   0.872895
# Blood Vessel    1.000000e+00  height    -0.000000   0.772113
# Brain           3.117000e-07     BMI     6.506263   7.904134
# Brain           1.000000e+00  height    -0.000000   0.002614
# Colon           1.780000e-01     BMI     0.749580   1.366532
# Colon           1.000000e+00  height    -0.000000   0.001305
# Fallopian Tube  7.600000e-01     BMI     0.119186   0.370590
# Fallopian Tube  1.000000e+00  height    -0.000000   0.193820
# Muscle          2.060000e-01     BMI     0.686133   1.236572
# Muscle          1.000000e+00  height    -0.000000   0.211832
# Nerve           8.000000e-03     BMI     2.096910   3.184622
# Nerve           1.000000e+00  height    -0.000000   0.020907
# Pancreas        6.700000e-02     BMI     1.173925   2.045757
# Pancreas        1.000000e+00  height    -0.000000   0.024109
# Pituitary       1.040000e-01     BMI     0.982967   1.677781
# Pituitary       1.000000e+00  height    -0.000000   0.004365
# Prostate        3.570000e-01     BMI     0.447332   0.826814
# Prostate        1.000000e+00  height    -0.000000   0.013228
# Skin            7.510000e-01     BMI     0.124360   0.407823
# Skin            1.000000e+00  height    -0.000000   0.101824
# Thyroid         6.000000e-01     BMI     0.221849   0.540608
# Thyroid         1.000000e+00  height    -0.000000   0.003051
# Uterus          6.700000e-02     BMI     1.173925   1.958607
# Uterus          1.000000e+00  height    -0.000000   0.164944
# Vagina          3.570000e-01     BMI     0.447332   0.804100
# Vagina          1.000000e+00  height    -0.000000   0.132533

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-87eeda163181> in <module>()
# ----> 1 csea_df.head()
#
# NameError: name 'csea_df' is not defined

# %%
# load brain-region-specific results
csea_df = pd.read_excel('../tables/CSEA_brain_rat_human_BMI_GIANT_sampling_210323.xlsx')
csea_df = csea_df[['Brain Regions and Development and P-Values',0.05]]
csea_df.columns=['Brain Region','tsea_threshold_0.05']

p_split = csea_df['tsea_threshold_0.05'].tolist()
p_list = [np.float(p.split(' ')[0]) for p in p_split]
FDR_list = [np.float(p.split(' ')[2].strip(')')) for p in p_split]

csea_df['p']=p_list
csea_df['FDR']=FDR_list
csea_df=csea_df.sort_values('p')
new_index = [i.split('.')[0] for i in csea_df['Brain Region'].tolist()]
csea_df.index=new_index
csea_df.head()
# Out:
#                             Brain Region tsea_threshold_0.05      p    FDR
# Cortex            Cortex.Young.Adulthood      0.007 ( 0.044)  0.007  0.044
# Thalamus        Thalamus.Young.Adulthood      0.041 ( 0.122)  0.041  0.122
# Cerebellum    Cerebellum.Young.Adulthood      0.113 ( 0.225)  0.113  0.225
# Hippocampus  Hippocampus.Young.Adulthood      0.473 ( 0.710)  0.473  0.710
# Amygdala        Amygdala.Young.Adulthood      0.695 ( 0.785)  0.695  0.785

# %%
plt.figure(figsize=(4,3))
plt.bar(np.arange(len(csea_df)),-np.log10(csea_df['p'].tolist()))
tmp=plt.xticks(np.arange(len(csea_df)),csea_df.index.tolist(),rotation='vertical')

plt.ylabel('-log10(p)')

plt.savefig('../manuscript/figures/figure3/csea_rat_human_BMI_210629.png',dpi=300,bbox_inches='tight')
# plt.savefig('../manuscript/figures/figure3/csea_rat_human_BMI_210323.svg')
