# %%
import warnings
import numpy as np
import pandas as pd
import random as rn
import requests
from mygene import MyGeneInfo
from scipy.stats import hypergeom
from statsmodels.stats import contingency_tables
from os.path import exists
import mygene
mg = mygene.MyGeneInfo()
import ddot
from ddot import Ontology

# %% [markdown]
# ## Questions
#
# 1. Should I be restricting mouse data to only human orthologs?
# 2. Should I be restricting community data to only mouse orthologs?
# 3. Are we using the contingency table correctly?
# 4. Is it worth doing any of this?

# %%
def load_MGI_mouseKO_data(url='http://www.informatics.jax.org/downloads/reports/MGI_PhenoGenoMP.rpt',
                          map_using="mygeneinfo", update=False):
    """
    Function to parse and load mouse knockout data from MGI.

    :param url: location of MGI knockout data
    :type url: str
    :return: parsed MGI knockout dataframe, including column for human orthologs
    :rtype: :py:class:`pandas.DataFrame`
    """
    # download MGI phenotype data
    if (not exists('MGI_PhenoGenoMP.rpt')) or update:
        r = requests.get(url, allow_redirects=True)
        open('MGI_PhenoGenoMP.rpt', 'wb').write(r.content)

    # parse the downloaded MGI phenotype data
    mgi_df = pd.read_csv('MGI_PhenoGenoMP.rpt', sep='\t',
                         names=['MGI_Allele_Accession_ID',
                                'Allele symbol', 'involves',
                                'MP', 'PMID', 'MGI_marker_accession_ID'])
    if map_using == "mygeneinfo":
        # extract gene names
        gene_name = [a.split('<')[0] for a in mgi_df['Allele symbol'].tolist()]
        mgi_df['gene_name'] = gene_name
        mgi_df.index = mgi_df['gene_name']
        # map mouse genes to human orthologs
        mouse_genes = list(np.unique(mgi_df['gene_name']))
        mg_mapped = mg.querymany(mouse_genes,
                                 as_dataframe=True, species=['mouse', 'human'],
                                 scopes='symbol', fields='symbol')
        # drop genes with no human ortholog
        print(len(mg_mapped))
        mg_mapped = mg_mapped.dropna(subset=['symbol'])
        print(len(mg_mapped))
        # drop duplicates
        mg_mapped = mg_mapped[~mg_mapped.index.duplicated(keep='first')]
        print(len(mg_mapped))
        mgi_df['human_ortholog'] = mgi_df['gene_name'].map(dict(mg_mapped['symbol']))
        return mgi_df

    elif map_using == "mgi":
        if not exists('MRK_List2.rpt') or update:
            keep_url = "http://www.informatics.jax.org/downloads/reports/MRK_List2.rpt"
            r_map = requests.get(keep_url, allow_redirects=True)
            open('MRK_List2.rpt', 'wb').write(r_map.content)
        keep = pd.read_csv('MRK_List2.rpt', sep="\t", usecols=["MGI Accession ID", "Marker Symbol",
                                                                     "Feature Type", "Marker Name"])
        keep = keep.loc[keep["Feature Type"].isin(["protein coding gene"])].reset_index(drop=True)
        mgi_df["MGI"] = mgi_df.MGI_marker_accession_ID.apply(lambda x: x.split("|"))
        mgi_df = mgi_df.explode("MGI", ignore_index=True)
        mgi_df["MGI"] = [mg if type(mg) is str else mg[0] for mg in mgi_df.MGI]
        mgi_df = mgi_df.loc[mgi_df["MGI"].isin(keep["MGI Accession ID"])]
        mgi_df = mgi_df.merge(keep.loc[:, ("MGI Accession ID", "Marker Symbol")], left_on="MGI",
                              right_on="MGI Accession ID", how="left")

        if not exists('HMD_HumanPhenotype.rpt') or update:
            map_url = "http://www.informatics.jax.org/downloads/reports/HMD_HumanPhenotype.rpt"
            r_map = requests.get(map_url, allow_redirects=True)
            open('HMD_HumanPhenotype.rpt', 'wb').write(r_map.content)
        mapping = pd.read_csv('HMD_HumanPhenotype.rpt', sep="\t", header=None, usecols=[0, 2, 3],
                              index_col=False, names=["symbol", "gene_name", "MGI"])
        mapping = mapping.loc[mapping["MGI"].isin(keep["MGI Accession ID"])]

        mg_mapped = mgi_df.merge(mapping, on="MGI", how="left")
        mg_mapped.loc[mg_mapped.symbol.isna(), "gene_name"] = mg_mapped.loc[mg_mapped.symbol.isna(), "Marker Symbol"]
        mg_mapped = mg_mapped.drop_duplicates()
        mg_mapped.rename(columns={"symbol": 'human_ortholog'}, inplace=True)
        return mg_mapped
    elif map_using == "mgi2":
        mgi_df["MGI_Allele_Accession_ID"] = mgi_df["MGI_Allele_Accession_ID"].apply(lambda x: re.sub("\([\s\*\/a-zA-Z0-9,-]+\)", "", x))
        mgi_df["allele_count"] = mgi_df.MGI_Allele_Accession_ID.apply(lambda x: len(x.split(",")))
        mgi_df["MGI"] = mgi_df.MGI_marker_accession_ID.apply(lambda x: x.split("|"))
        map_df = mgi_df[mgi_df.allele_count==1]
        map_df = map_df.explode(column="MGI")
        #map_df = map_df.assign(MGI=map_df.MGI.apply(lambda x: x[0]))
        #return map_df
        if not exists('MRK_List2.rpt') or update:
            keep_url = "http://www.informatics.jax.org/downloads/reports/MRK_List2.rpt"
            r_map = requests.get(keep_url, allow_redirects=True)
            open('MRK_List2.rpt', 'wb').write(r_map.content)
        keep = pd.read_csv('MRK_List2.rpt', sep="\t", usecols=["MGI Accession ID", "Marker Symbol",
                                                                     "Feature Type", "Marker Name"])
        map_df = map_df.merge(keep, left_on="MGI", right_on="MGI Accession ID")
        pc_df = map_df[map_df["Feature Type"]=="protein coding gene"]
        if not exists('HMD_HumanPhenotype.rpt') or update:
            map_url = "http://www.informatics.jax.org/downloads/reports/HMD_HumanPhenotype.rpt"
            r_map = requests.get(map_url, allow_redirects=True)
            open('HMD_HumanPhenotype.rpt', 'wb').write(r_map.content)
        hs = pd.read_csv('HMD_HumanPhenotype.rpt', sep="\t", header=None, usecols=[0, 2, 3],
                              index_col=False, names=["symbol", "gene_name", "MGI"])
        pc_df = pc_df.merge(hs, on="MGI", how="left")
        
        pc_df = pc_df.loc[:, ['MGI_Allele_Accession_ID', 'Allele symbol', 'involves', 'MP', 'PMID', 'MGI',
                              'Marker Symbol', 'Marker Name', 'symbol'] ]
        
        pc_df.rename(columns={"symbol": 'human_ortholog', "Marker Symbol": "gene_name"}, inplace=True)

        return pc_df


def load_MPO(url='http://www.informatics.jax.org/downloads/reports/MPheno_OBO.ontology', use_genes=False,
             mapping=None, restrict_to=None, use_display=False):
    """
    Function to parse and load mouse phenotype ontology, using DDOT's ontology module

    :param url: URL containing MPO ontology file
    :type url: str
    :param use_genes:
    :type use_genes: bool
    :param mapping:
    :type mapping:
    :param restrict_to:
    :type restrict_to:
    :param use_display:
    :type use_display: bool
    :return: MPO parsed using DDOT
    :rtype: :py:class:`ddot.Ontology`
    :raises ImportError: If DDOT package is not found
    """
    if use_genes:
        assert mapping is not None, "You must supply a mapping dataframe if use_genes==True"
    # download the mammalian phenotype ontology, parse with ddot
    r = requests.get(url, allow_redirects=True)
    open('MPheno_OBO.ontology', 'wb').write(r.content)
    ddot.parse_obo('MPheno_OBO.ontology',
                   'parsed_mp.txt',
                   'id2name_mp.txt',
                   'id2namespace_mp.txt',
                   'altID_mp.txt')

    MP2desc = pd.read_csv('id2name_mp.txt', sep='\t', names=['MP', 'description'], index_col='MP')

    MP2desc = MP2desc.loc[MP2desc.index.dropna()]  # drop NAN from index
    print(len(MP2desc))

    hierarchy = pd.read_table('parsed_mp.txt',
                              sep='\t',
                              header=None,
                              names=['Parent', 'Child', 'Relation', 'Namespace'])

    if use_display:
        from IPython.core.display import display
        display(MP2desc.head())
        display(hierarchy.head())

    if use_genes:  # map genes from `mapping` to terms in the ontology
        mouse_mapping = mapping.dropna().loc[:, ("human_ortholog", "MP")].reset_index()
        mouse_mapping = mouse_mapping.loc[:, ("human_ortholog", "MP")]
        mouse_mapping.columns = ["Gene", "Term"]
        if restrict_to is not None:  # restrict to specified subset of genes
            mouse_mapping = mouse_mapping.loc[mouse_mapping.Gene.isin(restrict_to)]
        # generate ontology using gene mapping
        MPO = Ontology.from_table(
            table=hierarchy,
            parent='Parent',
            child='Child',
            add_root_name='MP:00SUPER',
            ignore_orphan_terms=True,
            mapping=mouse_mapping,
            mapping_parent='Term',
            mapping_child='Gene')
    else:  # create the ontology without gene mappings
        MPO = Ontology.from_table(
            table=hierarchy,
            parent='Parent',
            child='Child',
            add_root_name='MP:00SUPER',
            ignore_orphan_terms=True)

    # add description to node attribute
    terms_keep = list(np.unique(hierarchy['Parent'].tolist()+hierarchy['Child'].tolist()))
    MPO.node_attr = MP2desc.loc[terms_keep]

    return MPO

# %%
mgi_df = load_MGI_mouseKO_data(map_using="mgi2", update=False)
mgi_df
# Out:
#    MGI_Allele_Accession_ID Allele symbol               involves          MP  \
# 0  Rb1<tm1Tyj>/Rb1<tm1Tyj>   Rb1<tm1Tyj>  involves: 129S2/SvPas  MP:0000600
# 1  Rb1<tm1Tyj>/Rb1<tm1Tyj>   Rb1<tm1Tyj>  involves: 129S2/SvPas  MP:0001716
# 2  Rb1<tm1Tyj>/Rb1<tm1Tyj>   Rb1<tm1Tyj>  involves: 129S2/SvPas  MP:0001698
# 3  Rb1<tm1Tyj>/Rb1<tm1Tyj>   Rb1<tm1Tyj>  involves: 129S2/SvPas  MP:0001092
# 4  Rb1<tm1Tyj>/Rb1<tm1Tyj>   Rb1<tm1Tyj>  involves: 129S2/SvPas  MP:0000961
#
#        PMID        MGI gene_name                       Marker Name  \
# 0  12529408  MGI:97874       Rb1  RB transcriptional corepressor 1
# 1  16449662  MGI:97874       Rb1  RB transcriptional corepressor 1
# 2  16449662  MGI:97874       Rb1  RB transcriptional corepressor 1
# 3  16449662  MGI:97874       Rb1  RB transcriptional corepressor 1
# 4  16449662  MGI:97874       Rb1  RB transcriptional corepressor 1
#
#   human_ortholog
# 0            RB1
# 1            RB1
# 2            RB1
# 3            RB1
# 4            RB1

# %%
MPO3 = load_MPO(use_genes=True, mapping=mgi_df)
# Out:
# 14555
# WARNING: Dropping 43549 duplicate gene-term connections

# %%
[MPO3.genes[x] for x in MPO3.term_2_gene["MP:0011940"]]
# Out:
# ['ABHD6',
#  'ACBD5',
#  'ACOT13',
#  'ADIPOQ',
#  'AGRP',
#  'AKR1B10',
#  'AKR1B15',
#  'ALK',
#  'ALKBH7',
#  'ARID5B',
#  'ATN1',
#  'C1QTNF5',
#  'CALCA',
#  'CAMKK2',
#  'CDKAL1',
#  'CHRM3',
#  'CIDEB',
#  'CISD2',
#  'CLDN12',
#  'CPT1C',
#  'CTF1',
#  'CTSD',
#  'CXCL14',
#  'CYP11A1',
#  'DLL1',
#  'DMBX1',
#  'DRD2',
#  'ENHO',
#  'ENPP1',
#  'FADS2',
#  'FBN1',
#  'FLNC',
#  'FOXO6',
#  'FTO',
#  'GCGR',
#  'GHSR',
#  'GLP1R',
#  'GPR82',
#  'HCN2',
#  'HDAC4',
#  'HILPDA',
#  'HNF4G',
#  'HRH1',
#  'HTR2C',
#  'HTR6',
#  'IMPACT',
#  'KCTD1',
#  'KRT6A',
#  'KRT6B',
#  'LEP',
#  'LYPD3',
#  'MAF1',
#  'MAPK8',
#  'MAPK8IP1',
#  'MFRP',
#  'MLXIPL',
#  'MYH1',
#  'NDUFA1',
#  'NEGR1',
#  'NMUR2',
#  'NPC1',
#  'NPFFR2',
#  'NPY1R',
#  'NPY5R',
#  'NPY6R',
#  'OPN3',
#  'OR4M1',
#  'OR4M2',
#  'PDE10A',
#  'PHOSPHO1',
#  'PLIN2',
#  'PMCH',
#  'PMCHL2',
#  'PPARG',
#  'PRCP',
#  'PRKAB1',
#  'PRLHR',
#  'PTGER1',
#  'QRFP',
#  'RAPGEF3',
#  'RCAN2',
#  'RMI1',
#  'SEMA3A',
#  'SIK2',
#  'SLC16A1',
#  'SLC27A5',
#  'SLC30A7',
#  'SLC52A3',
#  'SLC5A1',
#  'SLN',
#  'SNAP25',
#  'TAFA1',
#  'THRA',
#  'TNN',
#  'TRIB2',
#  'TRIM37',
#  'UCN2',
#  'ULK4',
#  'VIPR2',
#  'WFS1']

# %% [markdown]
# ## Original

# %%
mgi_orig = load_MGI_mouseKO_data(update=True)
# Out:
# querying 1-1000...done.
# querying 1001-2000...done.
# querying 2001-3000...done.
# querying 3001-4000...done.
# querying 4001-5000...done.
# querying 5001-6000...done.
# querying 6001-7000...done.
# querying 7001-8000...done.
# querying 8001-9000...done.
# querying 9001-10000...done.
# querying 10001-11000...done.
# querying 11001-12000...done.
# querying 12001-13000...done.
# querying 13001-14000...done.
# querying 14001-15000...done.
# querying 15001-16000...done.
# querying 16001-17000...done.
# querying 17001-18000...done.
# querying 18001-19000...done.
# querying 19001-20000...done.
# querying 20001-21000...done.
# querying 21001-22000...done.
# querying 22001-23000...done.
# querying 23001-24000...done.
# querying 24001-24140...done.
# Finished.
# 38 input query terms found dup hits:
# 	[('Abo', 3), ('Adam1a', 2), ('Adam1b', 2), ('Adam5', 2), ('Casp12', 2), ('Ccdc39', 2), ('Chaserr', 2
# 12251 input query terms found no hit:
# 	['+|Cav1', '+|Cm', '+|Del(10Prmt2-Pdxk)4Yey', '+|Del(11Mpo-Chad)18Brd', '+|Del(11Stat5a-Stat5b)1Mam'
# Pass "returnall=True" to return complete lists of duplicate or missing query terms.
# 24187
# 11936
# 11889

# %%
MPO_orig=load_MPO(use_genes=True, mapping=mgi_orig)
# Out:
# 14555
# WARNING: Dropping 58851 duplicate gene-term connections

# %%
# Out:
# 9948

# %%
nodes = nx.dfs_preorder_nodes(mp_graph, "MP:0002069")
nodes = [n for n in nodes]
orig_genes = []
new_genes = []
for node in nodes:
    print(node)
    orig_genes = set([MPO_orig.genes[n] for n in MPO_orig.term_2_gene[node]])
    new_genes = set([MPO3.genes[n] for n in MPO3.term_2_gene[node]])
    print(orig_genes.intersection(new_genes))
    print(orig_genes.union(new_genes))
    print("Original ", orig_genes.difference(new_genes))
    print("new ", new_genes.difference(orig_genes))
    print("\n")
# Out:
# MP:0002069
# set()
# set()
# Original  set()
# new  set()
#
#
# MP:0001422
# {'NEUROD4', 'SCT', 'UCN2', 'PTGS1', 'OXT', 'SCTR', 'TRPV4', 'PTGS2'}
# {'NEUROD4', 'SCT', 'UCN2', 'PTGS1', 'OXT', 'SCTR', 'TRPV4', 'PTGS2'}
# Original  set()
# new  set()
#
#
# MP:0001423
# {'ITPR3', 'NOS1', 'POU2F3', 'SLC18A2', 'DISC1', 'ACADS', 'ADORA2A'}
# {'ITPR3', 'NOS1', 'POU2F3', 'SLC18A2', 'DISC1', 'BDNF', 'EHMT1', 'ACADS', 'ADORA2A'}
# Original  {'BDNF', 'EHMT1'}
# new  set()
#
#
# MP:0001987
# {'SLC29A1', 'FAAH', 'CCL2', 'SLC6A1', 'EPS8', 'UNC79', 'CRHR1', 'TRPV1', 'GPR26', 'GABRB1', 'PRKCG'}
# {'SLC29A1', 'FAAH', 'SLC6A1', 'LINC02210-CRHR1', 'EPS8', 'TRPV1', 'GPR26', 'CCL2', 'CCL8', 'UNC79', 'CRHR1', 'GABRB1', 'PRKCG'}
# Original  set()
# new  {'LINC02210-CRHR1', 'CCL8'}
#
#
# MP:0002119
# set()
# set()
# Original  set()
# new  set()
#
#
# MP:0002570
# {'CCL2', 'CCR2', 'CACNA1B', 'DRD2', 'NPY2R', 'CCL3', 'MPDZ'}
# {'CCL3L1', 'CCR2', 'CCL3L3', 'MPDZ', 'CCL18', 'CCL2', 'CCL8', 'DRD2', 'NPY2R', 'CCL3', 'CACNA1B'}
# Original  set()
# new  {'CCL18', 'CCL3L1', 'CCL3L3', 'CCL8'}
#
#
# MP:0020379
# set()
# set()
# Original  set()
# new  set()
#
#
# MP:0001425
# {'POMC', 'PPP1R1B'}
# {'POMC', 'PPP1R1B'}
# Original  set()
# new  set()
#
#
# MP:0003545
# {'NOS1', 'SLC29A1', 'FAAH', 'CCL2', 'CCR2', 'GRIN1', 'ALK', 'POMC', 'EPS8', 'CCR5', 'SLC6A1', 'TAOK2', 'UNC79', 'TRPV1', 'NPY1R'}
# {'NOS1', 'SLC29A1', 'FAAH', 'CCR2', 'POMC', 'ALK', 'SLC6A1', 'EPS8', 'TAOK2', 'TRPV1', 'CCL2', 'GRIN1', 'CCR5', 'UNC79', 'CCL8', 'NPY1R'}
# Original  set()
# new  {'CCL8'}
#
#
# MP:0003546
# {'GRIA3', 'ALDH2', 'CCL2', 'CCR2', 'GRIN1', 'GNAS', 'SLC18A2', 'MPDZ', 'CACNA1B', 'DRD2', 'CCL3', 'GRM5', 'DRD3'}
# {'GRIA3', 'CCL3L1', 'ALDH2', 'CCR2', 'GNAS', 'CACNA1B', 'CCL3L3', 'MPDZ', 'CCL18', 'CCL2', 'SLC18A2', 'GRIN1', 'CCL8', 'DRD2', 'CCL3', 'GRM5', 'DRD3'}
# Original  set()
# new  {'CCL18', 'CCL3L3', 'CCL3L1', 'CCL8'}
#
#
# MP:0012042
# set()
# set()
# Original  set()
# new  set()
#
#
# MP:0001428
# {'HAX1'}
# {'HAX1', 'TH', 'WLS'}
# Original  {'TH', 'WLS'}
# new  set()
#
#
# MP:0005111
# {'AGRP', 'CHRM5'}
# {'AGRP', 'CHRM5'}
# Original  set()
# new  set()
#
#
# MP:0011737
# {'MMP17', 'FMR1'}
# {'MMP17', 'FMR1'}
# Original  set()
# new  set()
#
#
# MP:0011947
# {'AGTR2', 'PROKR1'}
# {'AGTR2', 'PROKR1'}
# Original  set()
# new  set()
#
#
# MP:0011941
# {'GRN', 'VDR', 'CCR2', 'NEDD4L', 'TAOK2', 'PPARG', 'NR1H4', 'VAMP8', 'UMOD', 'UNC5C', 'ITPR3', 'CTSA', 'AGT', 'CCL2', 'SLC14A1', 'HIF1AN', 'APRT', 'EPM2A', 'FOXA2', 'FXYD4', 'CCKBR', 'ACE', 'MTSS1', 'CCL3', 'NPY2R', 'SCUBE3', 'MARK4', 'SLC5A2', 'ADCY6', 'AVP', 'NPY4R', 'SLC14A2', 'WNT10A', 'SLC16A10', 'SYNM', 'CHRM3', 'AGPAT2', 'AGTR2', 'HTR1B', 'TGFB1', 'CCR5', 'UNC79', 'COL4A4', 'DRD2', 'GFRA2', 'APOE', 'GDF15', 'MCHR1'}
# {'VDR', 'CCR2', 'NEDD4L', 'TAOK2', 'PPARG', 'NR1H4', 'DICER1', 'CTSA', 'CCL2', 'HIF1AN', 'APRT', 'FXYD4', 'NPY2R', 'MTSS1', 'INS', 'DRD3', 'SCUBE3', 'SLC5A2', 'SCD', 'CCL3L3', 'SLC14A2', 'SYNM', 'AGTR2', 'SCD5', 'TGFB1', 'UNC79', 'INS-IGF2', 'APOE', 'GRN', 'AGTR1', 'VAMP8', 'UMOD', 'UNC5C', 'CCL18', 'ITPR3', 'AGT', 'SLC14A1', 'EPM2A', 'FOXA2', 'CCKBR', 'ACE', 'CCL3', 'MARK4', 'ADCY6', 'AVP', 'NPY4R', 'WNT10A', 'SLC16A10', 'CHRM3', 'AGPAT2', 'HTR1B', 'CCR5', 'CCL8', 'COL4A4', 'DRD2', 'GFRA2', 'GDF15', 'CCL3L1', 'MCHR1'}
# Original  {'DICER1', 'DRD3'}
# new  {'CCL3L1', 'AGTR1', 'SCD5', 'CCL8', 'SCD', 'CCL3L3', 'INS-IGF2', 'INS', 'CCL18'}
#
#
# MP:0001426
# {'GRN', 'CRH', 'CLN3', 'CDK4', 'AQP2', 'SLC2A9', 'AQP3', 'PSAP', 'MANF', 'SCTR', 'TRPV5', 'NPR3', 'AGT', 'ATP6V0A4', 'LCLAT1', 'PDSS2', 'FGF10', 'AVPR2', 'UOX', 'KCNJ1', 'LEPR', 'SLC12A1', 'IRS2', 'AFMID', 'GLIS2', 'AGPAT2', 'SIRT1', 'CD63', 'SCARB2', 'CEP290'}
# {'GRN', 'CLN3', 'CRH', 'CDK4', 'AQP2', 'SLC2A9', 'AQP3', 'MIR375', 'PSAP', 'MANF', 'SCTR', 'TRPV5', 'INSR', 'NPR3', 'AGT', 'ATP6V0A4', 'AKR1B1', 'LCLAT1', 'REN', 'SIX2', 'PDSS2', 'INS', 'FGF10', 'AVPR2', 'NOS1', 'UOX', 'NOS2', 'KCNJ1', 'FGFR1', 'CLDN10', 'LEPR', 'SLC12A1', 'IRS2', 'HPRT1', 'AFMID', 'GLIS2', 'AGPAT2', 'SIRT1', 'CD63', 'INS-IGF2', 'SCARB2', 'CEP290'}
# Original  {'INSR', 'NOS1', 'NOS2', 'MIR375', 'FGFR1', 'CLDN10', 'SIX2'}
# new  {'HPRT1', 'AKR1B1', 'REN', 'INS-IGF2', 'INS'}
#
#
# MP:0011942
# {'TRIM37', 'MMP17', 'PTGER1', 'PHOSPHO1', 'TRIB2', 'APLNR', 'BRS3', 'OPN3', 'ARHGAP17', 'TRPV4', 'STUB1', 'ADM', 'CISD2', 'TRPV1', 'CYP11B2', 'GABRA5', 'DRD2', 'DNAJC30', 'HNF4G', 'MYH1'}
# {'TRIM37', 'MMP17', 'PTGER1', 'PHOSPHO1', 'TRIB2', 'APLNR', 'BRS3', 'OPN3', 'ARHGAP17', 'TRPV4', 'STUB1', 'ADM', 'CISD2', 'CYP11B1', 'TRPV1', 'CYP11B2', 'GABRA5', 'STK11', 'DRD2', 'DNAJC30', 'HNF4G', 'MYH1'}
# Original  {'STK11'}
# new  {'CYP11B1'}
#
#
# MP:0011948
# set()
# set()
# Original  set()
# new  set()
#
#
# MP:0011949
# set()
# set()
# Original  set()
# new  set()
#
#
# MP:0011950
# set()
# set()
# Original  set()
# new  set()
#
#
# MP:0001431
# {'CACNA2D2', 'GPD2', 'LEP', 'PDYN', 'GNAS', 'TARDBP', 'HAP1', 'LRRC4B', 'CLOCK', 'ATP8A2', 'BBS12', 'MBOAT7', 'MAOA', 'BRD2', 'FOXP2', 'RUNX3', 'EIF2AK4', 'FTO', 'MARK2', 'GTF2IRD1', 'NFIC', 'TLR5', 'WFS1', 'AGRP', 'NPY2R', 'CCKBR', 'NCOA3', 'STAT3', 'ZEB1', 'MGLL', 'MC3R', 'ERRFI1', 'SLC34A1', 'NOS2', 'ACOT13', 'GATM', 'ADGRL3', 'HDAC4', 'NPY4R', 'LEPR', 'GPSM1', 'PNRC2', 'ZFHX3', 'NCOR2', 'GLB1', 'IGF2BP1', 'CSF1', 'APBA2', 'DUSP1', 'AGTR2', 'CRHR2', 'SCNN1A', 'NR2C2', 'OTC', 'SIK3', 'PTPRD', 'MAF', 'PEX7', 'NPY1R', 'IGFBP3', 'TOR1A'}
# {'CACNA2D2', 'GPD2', 'PDYN', 'GNAS', 'TARDBP', 'HAP1', 'CLOCK', 'ATP8A2', 'CES1', 'MBOAT7', 'BRD2', 'FOXP2', 'GHRHR', 'FTO', 'MARK2', 'NFIC', 'TLR5', 'HSD11B1', 'WFS1', 'AGRP', 'NPY2R', 'NCOA3', 'STAT3', 'MC3R', 'ACOT13', 'ADGRL3', 'SCD', 'LEPR', 'PSMC1', 'GPSM1', 'ZFHX3', 'IGF2BP1', 'CSF1', 'APBA2', 'AGTR2', 'MCAT', 'SCD5', 'SCNN1A', 'NR2C2', 'SIK3', 'PTPRD', 'JAG1', 'MAF', 'TOR1A', 'LRRC4B', 'BBS12', 'MAOA', 'RUNX3', 'EIF2AK4', 'GRIN1', 'GTF2IRD1', 'CCKBR', 'DBH', 'ZEB1', 'KLB', 'MGLL', 'ERRFI1', 'SLC34A1', 'NOS2', 'NTF3', 'GATM', 'HDAC4', 'NPY4R', 'PNRC2', 'FASN', 'NCOR2', 'GLB1', 'DUSP1', 'CRHR2', 'OTC', 'DRD2', 'LEP', 'PEX7', 'NPY1R', 'IGFBP3', 'CCKAR'}
# Original  {'MCAT', 'GHRHR', 'CCKAR', 'GRIN1', 'NTF3', 'HSD11B1', 'PSMC1', 'DRD2', 'JAG1', 'FASN', 'DBH', 'KLB'}
# new  {'SCD', 'CES1', 'SCD5'}
#
#
# MP:0001432
# {'PRLHR', 'EIF2AK4', 'PER2', 'FEZF2', 'CD36', 'HDAC4', 'PER1', 'CSK', 'BCAT2', 'OXT', 'RXFP4', 'ACADS'}
# {'PRLHR', 'PER2', 'HDAC4', 'CSK', 'RXFP4', 'ACADS', 'EIF2AK4', 'FEZF2', 'CD36', 'PER1', 'BCAT2', 'OXT'}
# Original  set()
# new  set()
#
#
# MP:0011976
# {'GPR83'}
# {'GPR83'}
# Original  set()
# new  set()
#
#
# MP:0002850
# {'UNC79', 'SLC6A1'}
# {'UNC79', 'SLC6A1'}
# Original  set()
# new  set()
#
#
# MP:0012308
# set()
# set()
# Original  set()
# new  set()
#
#
# MP:0012347
# {'ITPR3', 'ATP2B1', 'DISC1'}
# {'ITPR3', 'ATP2B1', 'DISC1'}
# Original  set()
# new  set()
#
#
# MP:0031056
# set()
# set()
# Original  set()
# new  set()
#
#
# MP:0031057
# set()
# set()
# Original  set()
# new  set()
#
#
# MP:0001436
# {'SNRPN', 'PPP1R15B', 'RLN1', 'NR4A2', 'DHCR7', 'GNB1', 'CHRNA7', 'SEC23B', 'COPB2', 'GK', 'GJA1', 'PROC', 'GAD1', 'MMUT', 'EIF2S1', 'BIN1', 'EHMT1', 'TOR1A', 'TASP1', 'GNAL', 'SALL1', 'FGF9', 'MAGEL2', 'PHF21A', 'CPEB4', 'GPHN', 'GRIN1', 'KCNJ2', 'CDKN1C', 'DPP9', 'CFL2', 'MYH10', 'SLC27A4', 'TGFB3', 'STRADA', 'ZDHHC16', 'GSC', 'LGR5', 'DNM1', 'NEUROG1', 'DGAT2', 'PEX11B', 'BCL11B', 'DLX5', 'HSD11B2', 'NEUROG2', 'GNAS', 'HAP1', 'FKBP8', 'SPAG17', 'FOXF2', 'DACH1', 'UBR3', 'SLC6A9', 'MAPK6', 'JAK1', 'KIF2A', 'SYT1', 'EN1', 'HELT', 'FYN', 'LOX', 'PPME1', 'CRLF1', 'FUS', 'ZIC1', 'GTF2A1', 'KLF4', 'CYS1', 'HOXA2', 'TGM1', 'SYNGAP1', 'POU2F2', 'GRIN2B', 'PROX1', 'ILF3', 'DLX2', 'HAND2', 'CASK', 'NEB', 'DCC', 'MARCKS', 'LPAR1', 'ZEB1', 'LMX1B', 'NTF3', 'GRID2', 'LMNA', 'CHRNG', 'MN1', 'ARAF', 'SALL3'}
# {'WNT3A', 'SNRPN', 'PPP1R15B', 'RLN1', 'NR4A2', 'DHCR7', 'GNB1', 'ACVR1', 'CHRNA7', 'SEC23B', 'COPB2', 'HSD17B4', 'GJA6P', 'GRM7', 'GK', 'GJA1', 'PROC', 'GAD1', 'MMUT', 'EIF2S1', 'PIGA', 'BIN1', 'EHMT1', 'TOR1A', 'FOXG1', 'TASP1', 'GNAL', 'SALL1', 'REG1A', 'FGF9', 'NEUROD6', 'MAGEL2', 'HOXA1', 'HRAS', 'PHF21A', 'CPEB4', 'GPHN', 'CCND1', 'BMPR1A', 'GRIN1', 'KCNJ2', 'CDKN1C', 'DPP9', 'CFL2', 'MYH10', 'SLC27A4', 'TGFB3', 'STRADA', 'ZDHHC16', 'ELP1', 'GSC', 'LGR5', 'DNM1', 'NEUROG1', 'DGAT2', 'PEX11B', 'BCL11B', 'DLX5', 'HSD11B2', 'NEUROG2', 'GNAS', 'HAP1', 'FKBP8', 'SPAG17', 'FOXF2', 'DACH1', 'UBR3', 'OGT', 'SLC6A9', 'MAPK6', 'CDC42', 'JAK1', 'KIF2A', 'INSL4', 'SYT1', 'EN1', 'HELT', 'FYN', 'LOX', 'PPME1', 'CRLF1', 'PLEC', 'FUS', 'ZIC1', 'GTF2A1', 'KLF4', 'CYS1', 'HOXA2', 'TGM1', 'POU2F2', 'SYNGAP1', 'GRIN2B', 'PROX1', 'ILF3', 'DLX2', 'HAND2', 'CASK', 'NEB', 'DCC', 'MARCKS', 'LPAR1', 'ZEB1', 'RLN2', 'LMX1B', 'NTF3', 'GRID2', 'LMNA', 'CHRFAM7A', 'CHRNG', 'MN1', 'ARAF', 'SALL3', 'REG1B'}
# Original  {'FOXG1', 'WNT3A', 'CDC42', 'CCND1', 'BMPR1A', 'HSD17B4', 'ELP1', 'PIGA', 'HRAS', 'NEUROD6', 'PLEC', 'OGT', 'GRM7', 'HOXA1', 'ACVR1'}
# new  {'RLN2', 'INSL4', 'GJA6P', 'REG1A', 'CHRFAM7A', 'REG1B'}
#
#
# MP:0001437
# {'NTRK2', 'DHCR7', 'PTS', 'NR2F1'}
# {'NR2F1', 'DHCR7', 'NTRK2', 'PTS'}
# Original  set()
# new  set()
#
#
# MP:0020863
# set()
# set()
# Original  set()
# new  set()
#
#
# MP:0001435
# {'INHBA', 'CLCF1', 'KCNJ13', 'DYNC1H1', 'POU4F1', 'CNTFR', 'CDK5', 'GRIN1', 'IGF2R', 'ABCA12', 'SLC27A4', 'DHCR7', 'HAND2', 'NTRK2', 'GRIN2B'}
# {'INHBA', 'CLCF1', 'DYNC1H1', 'POU4F1', 'CDK5', 'IGF2R', 'SLC27A4', 'DHCR7', 'HAND2', 'NTRK2', 'CNTFR', 'KCNJ13', 'GRIN1', 'ABCA12', 'GRIN2B'}
# Original  set()
# new  set()
#
#
# MP:0020864
# {'SHANK3'}
# {'SHANK3'}
# Original  set()
# new  set()
#
#
# MP:0020865
# set()
# set()
# Original  set()
# new  set()
#
#
# MP:0005449
# {'CRH', 'ME1', 'E2F4', 'PSAP', 'IL1R1', 'CARTPT', 'GIGYF2', 'CLOCK', 'MC4R', 'TNF', 'SLC17A7', 'NPY6R', 'RXFP4', 'NMUR2', 'PRKAR2B', 'SDC3', 'BRS3', 'RSC1A1', 'GRIN1', 'IL6', 'CIBAR1', 'CNR1', 'AGRP', 'CRHR1', 'NPY2R', 'NFKB2', 'NOX3', 'ITGA11', 'CCDC80', 'DBH', 'HTR4', 'DRD3', 'MC3R', 'ASL', 'ACSS1', 'ATP1B2', 'SCUBE3', 'CFL2', 'PER2', 'CRHBP', 'NTF3', 'GRPR', 'SH3KBP1', 'NPY4R', 'LEPR', 'FGF21', 'PITX3', 'KCNJ11', 'SCP2', 'GHRL', 'GBA', 'GHSR', 'CBL', 'CRHR2', 'DNAJC3', 'GHR', 'GLP1R', 'CD36', 'BSX', 'UCP2', 'PER1', 'WASF1', 'PTPN1', 'LEP', 'GFRAL', 'DMBX1', 'CCKAR'}
# {'CRH', 'E2F4', 'MC4R', 'TNF', 'NPY6R', 'RXFP4', 'SLC17A7', 'JPH3', 'SDC3', 'RSC1A1', 'CIBAR1', 'HSD11B1', 'AGRP', 'CRHR1', 'NPY2R', 'NOX3', 'ITGA11', 'CCDC80', 'HTR4', 'DRD3', 'MC3R', 'SCUBE3', 'ACSS1', 'CRHBP', 'GRPR', 'LEPR', 'SCP2', 'KCNJ11', 'GHRL', 'GBA', 'GHSR', 'CBL', 'GHR', 'GLP1R', 'CD36', 'BSX', 'PER1', 'GLUL', 'WASF1', 'GFRAL', 'DMBX1', 'ME1', 'PSAP', 'IL1R1', 'CARTPT', 'GIGYF2', 'ITPR3', 'NMUR2', 'PRKAR2B', 'BRS3', 'GRIN1', 'IL6', 'CNR1', 'NFKB2', 'OXT', 'DBH', 'ASL', 'ATP1B2', 'CFL2', 'PER2', 'NTF3', 'LINC02210-CRHR1', 'ASIP', 'SH3KBP1', 'NPY4R', 'FGF21', 'SNORD116', 'PITX3', 'IGHMBP2', 'DNAJC3', 'CRHR2', 'UCP2', 'PTPN1', 'LEP', 'ZNF423', 'CLOCK', 'CCKAR'}
# Original  {'IGHMBP2', 'ITPR3', 'HSD11B1', 'OXT', 'GLUL', 'SNORD116', 'JPH3'}
# new  {'ZNF423', 'LINC02210-CRHR1', 'ASIP'}
#
#
# MP:0001438
# {'OLIG2', 'PRRX1', 'EVC', 'EPS15L1', 'SLC4A2', 'ZMPSTE24', 'ITGB4', 'LGI1', 'GRIN1', 'ILK', 'EN1', 'SOCS7', 'DYNC1H1', 'POU4F1', 'PEX13', 'PEX2', 'CASR', 'TCF15', 'ACAN', 'PRX', 'TBR1', 'GBA', 'ROBO1', 'HOXA2', 'HAX1', 'FOXD1', 'CFTR', 'TGM1', 'RFX6', 'LAMC2', 'TSHZ1'}
# {'OLIG2', 'EVC', 'EPS15L1', 'PRRX1', 'SLC4A2', 'ITGB4', 'ZMPSTE24', 'LGI1', 'UBA6', 'GRIN1', 'ILK', 'EN1', 'RFX6', 'SOCS7', 'DBH', 'DYNC1H1', 'POU4F1', 'PEX13', 'PEX2', 'CASR', 'TCF15', 'TH', 'ACAN', 'PRX', 'TBR1', 'GBA', 'ROBO1', 'HOXA2', 'HAX1', 'FOXD1', 'CFTR', 'DRD2', 'PRRX2', 'TGM1', 'PAX9', 'LAMC2', 'TSHZ1'}
# Original  {'UBA6', 'TH', 'DRD2', 'PRRX2', 'PAX9', 'DBH'}
# new  set()
#
#
# MP:0009546
# {'SNRPN', 'RLN1', 'PGAP1', 'DHCR7', 'TLX3', 'GSX2', 'CERS3', 'CEBPA', 'ATP6V0A1', 'SLC23A1', 'GAD1', 'DMTF1', 'BCLAF1', 'MMUT', 'GNE', 'PKDCC', 'SLC18A2', 'PSIP1', 'UNC79', 'SH3PXD2A', 'EHMT1', 'TOR1A', 'EPS15L1', 'HOXC4', 'FGFR3', 'IRX1', 'SRSF5', 'MAGEL2', 'DMRTA2', 'SCYL2', 'CPEB4', 'GRIN1', 'CDKN1C', 'DPP9', 'ERRFI1', 'POU4F1', 'DLG1', 'SLC27A4', 'TGFB3', 'GSC', 'ARFGEF1', 'KRT5', 'LGR5', 'ASCL1', 'MSX1', 'BCL11B', 'DLX5', 'GNAS', 'HAP1', 'NTN1', 'SPAG17', 'FOXF2', 'DACH1', 'SLC6A9', 'PNPLA1', 'FSCN1', 'CEP55', 'SCN2A', 'USF2', 'SYNE1', 'CRLF1', 'RUNX1T1', 'DERL2', 'ATG5', 'CYP1A2', 'GBA', 'GRB2', 'JPH1', 'KLF7', 'ESRRG', 'GRIN2B', 'DMBX1', 'PCK1', 'TCF7L2', 'ALX1', 'PEG3', 'DHRS3', 'ST14', 'G0S2', 'BRINP1', 'ATF5', 'FBXL12', 'PRTG', 'MNT', 'PIP5K1C', 'PCCA', 'GRID2', 'SH2D3C', 'AFAP1', 'UNC13A', 'SAFB', 'MRAP'}
# {'SNRPN', 'EZH1', 'RLN1', 'PGAP1', 'DHCR7', 'TLX3', 'SH3GL2', 'GSX2', 'TP63', 'CERS3', 'CEBPA', 'ATP6V0A1', 'SLC23A1', 'GAD1', 'DMTF1', 'BCLAF1', 'MMUT', 'GNE', 'PKDCC', 'SLC18A2', 'PSIP1', 'UNC79', 'SH3PXD2A', 'DNM3', 'EHMT1', 'TOR1A', 'FOXG1', 'EPS15L1', 'HOXC4', 'FGFR3', 'IRX1', 'SRSF5', 'MAGEL2', 'DMRTA2', 'USP7', 'SCYL2', 'CPEB4', 'SNAP29', 'GRIN1', 'CDKN1C', 'ISL1', 'SPIN1', 'DPP9', 'ERRFI1', 'POU4F1', 'DLG1', 'SLC27A4', 'TGFB3', 'SPINT1', 'ALX4', 'ELP1', 'NEURL1', 'GSC', 'ARFGEF1', 'KRT5', 'LGR5', 'ASCL1', 'DRD2', 'MSX1', 'BCL11B', 'TRIO', 'DLX5', 'GNAS', 'HAP1', 'NTN1', 'SPAG17', 'FOXF2', 'DACH1', 'MSX2', 'SLC6A9', 'CDC42', 'KIF13B', 'PNPLA1', 'INSL4', 'EN1', 'FSCN1', 'PDSS2', 'APLP2', 'CEP55', 'SCN2A', 'USF2', 'SYNE1', 'CRLF1', 'DNM1L', 'RUNX1T1', 'DERL2', 'ATG5', 'CYP1A2', 'GBA', 'ROBO1', 'GRB2', 'JPH1', 'KLF7', 'ESRRG', 'GRIN2B', 'DMBX1', 'PCK1', 'TCF7L2', 'ALX1', 'PEG3', 'DHRS3', 'ST14', 'G0S2', 'BRINP1', 'ATF5', 'FBXL12', 'PRTG', 'MNT', 'PIP5K1C', 'RLN2', 'PCCA', 'GRID2', 'SH2D3C', 'AFAP1', 'UNC13A', 'SAFB', 'MRAP'}
# Original  {'FOXG1', 'TRIO', 'EZH1', 'MSX2', 'USP7', 'CDC42', 'KIF13B', 'SNAP29', 'EN1', 'SH3GL2', 'ISL1', 'PDSS2', 'SPIN1', 'APLP2', 'SPINT1', 'DNM1L', 'ALX4', 'ELP1', 'ROBO1', 'DRD2', 'DNM3'}
# new  {'RLN2', 'NEURL1', 'INSL4', 'TP63'}
#
#
# MP:0002849
# {'UNC79'}
# {'UNC79'}
# Original  set()
# new  set()
#
#
# MP:0003158
# {'COL19A1', 'LDB3', 'CDKN1C'}
# {'IGHMBP2', 'PDSS2', 'UCHL1', 'CDKN1C', 'COL19A1', 'LDB3'}
# Original  {'IGHMBP2', 'PDSS2', 'UCHL1'}
# new  set()
#
#
# MP:0011939
# {'CSF2', 'SLURP1', 'TAFA1', 'NR1H4', 'MC4R', 'BBS1', 'NPY6R', 'HSD11B1', 'FXYD4', 'BCAT2', 'TNKS', 'OTP', 'CEBPA', 'SLC5A2', 'ACOT13', 'LEPR', 'APOA4', 'SQSTM1', 'ACER1', 'C1QTNF9', 'HRH1', 'LIPA', 'GHR', 'HTR2C', 'PRLH', 'CIDEC', 'FMO5', 'VEGFD', 'UMOD', 'APMAP', 'TMEM18', 'LIPE', 'ACE', 'CCKBR', 'ITPRID2', 'C5AR2', 'PTTG1', 'MRAP2', 'NOS2', 'FFAR1', 'FOLH1', 'CYB5R4', 'ARID5B', 'SIRT7', 'ATP2B1', 'DRD2', 'LEP', 'BBIP1', 'GDF15', 'APOE', 'SNAP25', 'MCHR1', 'POMC', 'GNAS', 'TUB', 'ARV1', 'HILPDA', 'ROCK1', 'FTO', 'PLIN1', 'HIF1AN', 'ALDH3A2', 'AGRP', 'SLC25A25', 'CCDC80', 'ATM', 'ALMS1', 'LMTK3', 'RAI1', 'NUCKS1', 'ACOT11', 'BBS7', 'GPR61', 'TGFB1', 'APOC3', 'TLR2', 'MSTN', 'ADIPOR2', 'GRN', 'PLEKHN1', 'ACTB', 'NCOR1', 'CDO1', 'BECN2', 'UNC5C', 'OSMR', 'MBOAT4', 'BRS3', 'FOXA2', 'GPR50', 'ZEB1', 'BSCL2', 'PPP1R3G', 'HDAC4', 'GPR26', 'SGK3', 'AGPAT2', 'SIRT1', 'GFRA2', 'CAV1'}
# {'CSF2', 'SLURP1', 'C8orf44-SGK3', 'TAFA1', 'NR1H4', 'MC4R', 'BBS1', 'NPY6R', 'HSD11B1', 'FXYD4', 'BCAT2', 'TNKS', 'DRD3', 'OTP', 'CEBPA', 'SLC5A2', 'ACOT13', 'LEPR', 'APOA4', 'SQSTM1', 'ACER1', 'C1QTNF9', 'HRH1', 'LIPA', 'GHR', 'HTR2C', 'PRLH', 'CIDEC', 'PTTG3P', 'FMO5', 'VEGFD', 'UMOD', 'APMAP', 'TMEM18', 'LIPE', 'C1QTNF9B', 'ACE', 'CCKBR', 'ITPRID2', 'LDLR', 'C5AR2', 'PTTG1', 'MRAP2', 'NOS2', 'ASIP', 'FFAR1', 'GLP2R', 'FOLH1', 'CYB5R4', 'ARID5B', 'SIRT7', 'ATP2B1', 'FOLH1B', 'DRD2', 'LEP', 'BBIP1', 'GDF15', 'APOE', 'SNAP25', 'MCHR1', 'POMC', 'GNAS', 'TUB', 'ARV1', 'HILPDA', 'ROCK1', 'FTO', 'PLIN1', 'HIF1AN', 'ALDH3A2', 'AGRP', 'SLC25A25', 'CCDC80', 'INS', 'ATM', 'NOS1', 'PDPK1', 'ALMS1', 'LMTK3', 'RAI1', 'NUCKS1', 'ACOT11', 'BBS7', 'GPR61', 'TGFB1', 'APOC3', 'TLR2', 'MSTN', 'ADIPOQ', 'INS-IGF2', 'ADIPOR2', 'GRN', 'PLEKHN1', 'ACTB', 'NCOR1', 'CDO1', 'BECN2', 'PRKCI', 'UNC5C', 'OSMR', 'MBOAT4', 'CDKN1A', 'BRS3', 'PMCH', 'FOXA2', 'PTTG2', 'DBH', 'GPR50', 'ZEB1', 'BSCL2', 'PPP1R3G', 'HDAC4', 'CCDC7', 'GPR26', 'SGK3', 'AGPAT2', 'SIRT1', 'GFRA2', 'CAV1'}
# Original  {'NOS1', 'CDKN1A', 'PDPK1', 'PRKCI', 'PMCH', 'ADIPOQ', 'GLP2R', 'LDLR', 'DBH', 'DRD3'}
# new  {'PTTG3P', 'C8orf44-SGK3', 'ASIP', 'C1QTNF9B', 'FOLH1B', 'INS-IGF2', 'CCDC7', 'PTTG2', 'INS'}
#
#
# MP:0001433
# {'CLPS', 'CLIC5', 'BBS2', 'ARNT2', 'CPE', 'CRTC1', 'PLEKHN1', 'POMC', 'SCG5', 'TARDBP', 'MC4R', 'HRH3', 'PRKAG2', 'SIM1', 'ANKRD26', 'PRKAR2B', 'SDC3', 'BRS3', 'NTSR1', 'FTO', 'LCLAT1', 'ADRB3', 'TLR5', 'NPY5R', 'EPM2A', 'PANK1', 'NMU', 'NPY2R', 'NPBWR1', 'BDNF', 'PYY', 'CLTRN', 'HNF1A', 'ACACB', 'MARK4', 'MRAP2', 'BSCL2', 'PCSK1', 'CEP19', 'PIK3CA', 'LEPR', 'RAI1', 'C3', 'NHLH2', 'IRS2', 'BBS4', 'IL18', 'GPR61', 'BBS10', 'CBL', 'HTR2C', 'SIRT1', 'GUCY2C', 'MPZL3', 'LEP', 'BBIP1', 'GFRAL', 'MCHR1', 'TCF7L2'}
# {'ARNT2', 'CPE', 'CRTC1', 'CEACAM8', 'POMC', 'PPARG', 'TARDBP', 'MC4R', 'HRH3', 'SLC32A1', 'PSG2', 'PRKAG2', 'ANKRD26', 'PSG11', 'SDC3', 'PSG6', 'CEACAM6', 'FTO', 'TLR5', 'NPY5R', 'NMU', 'NPY2R', 'CEACAM5', 'NPBWR1', 'BDNF', 'PYY', 'PSG9', 'INS', 'PSG8', 'ACACB', 'CEP19', 'SCD', 'RAI1', 'LEPR', 'NHLH2', 'GPR61', 'BBS10', 'CEACAM21', 'CBL', 'HTR2C', 'SCD5', 'CEACAM4', 'BSX', 'INS-IGF2', 'ATE1', 'CEACAM1', 'GFRAL', 'TCF7L2', 'BBS4', 'CLPS', 'CLIC5', 'BBS2', 'PLEKHN1', 'SCG5', 'PSG3', 'PSG1', 'TLR4', 'SIM1', 'PYY3', 'PRKAR2B', 'INSR', 'ANKRD62', 'CEACAM3', 'BRS3', 'NTSR1', 'LCLAT1', 'ADRB3', 'EPM2A', 'PANK1', 'CLTRN', 'HNF1A', 'PSG4', 'MARK4', 'MRAP2', 'BSCL2', 'PCSK1', 'STAT5B', 'PIK3CA', 'SNORD116', 'C3', 'CEACAM7', 'IRS2', 'IL18', 'SIRT1', 'PSG5', 'MPZL3', 'LEP', 'BBIP1', 'MCHR1', 'GUCY2C'}
# Original  {'INSR', 'SNORD116', 'STAT5B', 'PPARG', 'BSX', 'SLC32A1', 'ATE1', 'TLR4'}
# new  {'CEACAM8', 'PSG3', 'PSG1', 'PSG2', 'PYY3', 'PSG11', 'ANKRD62', 'CEACAM3', 'PSG6', 'CEACAM6', 'CEACAM5', 'PSG9', 'INS', 'PSG8', 'PSG4', 'SCD', 'CEACAM7', 'CEACAM21', 'SCD5', 'CEACAM4', 'PSG5', 'INS-IGF2', 'CEACAM1'}
#
#
# MP:0011958
# {'MRAP2', 'PRLH', 'P2RX7', 'GUCY2C'}
# {'PRLH', 'P2RX7', 'MRAP2', 'PRKAA2', 'GUCY2C'}
# Original  {'PRKAA2'}
# new  set()
#
#
# MP:0011940
# {'ENHO', 'RAPGEF3', 'PLIN2', 'MAPK8', 'TRIM37', 'TAFA1', 'DLL1', 'LYPD3', 'NPY6R', 'ABHD6', 'SLC27A5', 'UCN2', 'NPY5R', 'PRCP', 'WFS1', 'CPT1C', 'CTF1', 'THRA', 'ENPP1', 'ULK4', 'PRLHR', 'FLNC', 'ACOT13', 'RMI1', 'HRH1', 'GCGR', 'HTR2C', 'HNF4G', 'MYH1', 'RCAN2', 'PTGER1', 'SEMA3A', 'SLC30A7', 'NMUR2', 'NPFFR2', 'HTR6', 'IMPACT', 'HCN2', 'ALKBH7', 'SLN', 'CISD2', 'MAPK8IP1', 'SLC5A1', 'CXCL14', 'ARID5B', 'SIK2', 'DRD2', 'LEP', 'SNAP25', 'NPY1R', 'FBN1', 'CYP11A1', 'PPARG', 'MLXIPL', 'VIPR2', 'NEGR1', 'PRKAB1', 'CIDEB', 'HILPDA', 'FTO', 'TNN', 'OPN3', 'NDUFA1', 'AGRP', 'C1QTNF5', 'KCTD1', 'CLDN12', 'SLC16A1', 'MAF1', 'ACBD5', 'SLC52A3', 'GHSR', 'GLP1R', 'ADIPOQ', 'DMBX1', 'CAMKK2', 'PDE10A', 'ALK', 'GPR82', 'PHOSPHO1', 'TRIB2', 'CTSD', 'CALCA', 'PMCH', 'FADS2', 'HDAC4', 'CHRM3', 'CDKAL1', 'NPC1', 'ATN1', 'QRFP', 'FOXO6'}
# {'ENHO', 'RAPGEF3', 'PLIN2', 'MAPK8', 'TRIM37', 'TAFA1', 'DLL1', 'LYPD3', 'NPY6R', 'ABHD6', 'OR4M1', 'NEAT1', 'SLC27A5', 'UCN2', 'NPY5R', 'PRCP', 'WFS1', 'CPT1C', 'CTF1', 'ENPP1', 'THRA', 'ULK4', 'PRLHR', 'FLNC', 'ACOT13', 'DBX1', 'RMI1', 'HRH1', 'GCGR', 'HTR2C', 'HNF4G', 'MYH1', 'MYLK', 'BRAF', 'RCAN2', 'PTGER1', 'SEMA3A', 'SLC30A7', 'NMUR2', 'OR4M2', 'NPFFR2', 'KRT6A', 'MFRP', 'HTR6', 'IMPACT', 'HCN2', 'ALKBH7', 'SLN', 'CISD2', 'MAPK8IP1', 'SLC5A1', 'CXCL14', 'ARID5B', 'AKR1B15', 'SIK2', 'DRD2', 'LEP', 'SNAP25', 'NPY1R', 'PMCHL2', 'FBN1', 'POMC', 'CYP11A1', 'PPARG', 'MLXIPL', 'TNFRSF1A', 'VIPR2', 'NEGR1', 'PRKAB1', 'CIDEB', 'HILPDA', 'FTO', 'TNN', 'OPN3', 'EN1', 'NDUFA1', 'AGRP', 'C1QTNF5', 'KCTD1', 'CLDN12', 'BRPF1', 'SLC16A1', 'MAF1', 'ACBD5', 'SLC52A3', 'GHSR', 'GLP1R', 'ADIPOQ', 'DMBX1', 'CAMKK2', 'PDE10A', 'MYD88', 'ALK', 'SOD2', 'GPR82', 'PHOSPHO1', 'TRIB2', 'CTSD', 'CALCA', 'PMCH', 'PPARGC1A', 'DBH', 'EIF4B', 'FADS2', 'HDAC4', 'ATF3', 'CHRM3', 'CDKAL1', 'NPC1', 'AKR1B10', 'ATN1', 'QRFP', 'KRT6B', 'PTPN1', 'FOXO6'}
# Original  {'MYLK', 'BRPF1', 'BRAF', 'NEAT1', 'MYD88', 'POMC', 'SOD2', 'DBX1', 'EN1', 'PPARGC1A', 'TNFRSF1A', 'EIF4B', 'ATF3', 'PTPN1', 'DBH'}
# new  {'OR4M2', 'PMCHL2', 'AKR1B10', 'KRT6A', 'KRT6B', 'MFRP', 'AKR1B15', 'OR4M1'}
#
#
# MP:0011957
# {'CAMKK2', 'MC3R', 'NMUR2', 'UBB', 'GPR39', 'POMC', 'GALP', 'OXT', 'MAGEL2', 'RCAN2', 'RXFP4', 'NPY1R'}
# {'CAMKK2', 'MC3R', 'POMC', 'GALP', 'DBX1', 'MAGEL2', 'FASN', 'RCAN2', 'RXFP4', 'DBH', 'NMUR2', 'UBB', 'NPY1R', 'OXT', 'GPR39'}
# Original  {'DBX1', 'FASN', 'DBH'}
# new  set()
#
#
# MP:0008819
# {'GTF2IRD1'}
# {'GTF2IRD1'}
# Original  set()
# new  set()
#
#
# MP:0011943
# {'HRH1'}
# {'INSR', 'HRH1'}
# Original  {'INSR'}
# new  set()
#
#
# MP:0011944
# set()
# set()
# Original  set()
# new  set()
#
#
# MP:0011945
# {'RHBDF1', 'TAFA1'}
# {'GLP2R', 'RHBDF1', 'TAFA1'}
# Original  {'GLP2R'}
# new  set()
#
#
# MP:0011946
# set()
# set()
# Original  set()
# new  set()
#
#
# MP:0011956
# set()
# set()
# Original  set()
# new  set()

# %% [markdown]
# ## From GenoPheno

# %%
mgi_new = load_MGI_mouseKO_data(map_using="mgi", update=True)

# %%
MPO_new=load_MPO(use_genes=True, mapping=mgi_new)
# Out:
# 14555
# WARNING: Dropping 94281 duplicate gene-term connections

# %%
mgi_new.head()
# Out:
#    MGI_Allele_Accession_ID Allele symbol               involves          MP  \
# 0  Rb1<tm1Tyj>/Rb1<tm1Tyj>   Rb1<tm1Tyj>  involves: 129S2/SvPas  MP:0000600
# 1  Rb1<tm1Tyj>/Rb1<tm1Tyj>   Rb1<tm1Tyj>  involves: 129S2/SvPas  MP:0001716
# 2  Rb1<tm1Tyj>/Rb1<tm1Tyj>   Rb1<tm1Tyj>  involves: 129S2/SvPas  MP:0001698
# 3  Rb1<tm1Tyj>/Rb1<tm1Tyj>   Rb1<tm1Tyj>  involves: 129S2/SvPas  MP:0001092
# 4  Rb1<tm1Tyj>/Rb1<tm1Tyj>   Rb1<tm1Tyj>  involves: 129S2/SvPas  MP:0000961
#
#        PMID MGI_marker_accession_ID        MGI MGI Accession ID Marker Symbol  \
# 0  12529408               MGI:97874  MGI:97874        MGI:97874           Rb1
# 1  16449662               MGI:97874  MGI:97874        MGI:97874           Rb1
# 2  16449662               MGI:97874  MGI:97874        MGI:97874           Rb1
# 3  16449662               MGI:97874  MGI:97874        MGI:97874           Rb1
# 4  16449662               MGI:97874  MGI:97874        MGI:97874           Rb1
#
#   human_ortholog gene_name
# 0            RB1       Rb1
# 1            RB1       Rb1
# 2            RB1       Rb1
# 3            RB1       Rb1
# 4            RB1       Rb1

# %%
import networkx as nx
def _get_mp_graph(datafile="parsed_mp.txt"):
    mp_data = pd.read_csv(datafile, sep="\t", header=None)
    mp_data.head()
    mp_graph = nx.from_pandas_edgelist(mp_data, 0,1, create_using=nx.DiGraph)
    return mp_graph

mp_graph = _get_mp_graph()

# %%
nodes = nx.dfs_preorder_nodes(mp_graph, "MP:0002069")
nodes = [n for n in nodes]

# %%
orig_genes = []
new_genes = []
for node in nodes:
    print(node)
    orig_genes = set([MPO_orig.genes[n] for n in MPO_orig.term_2_gene[node]])
    new_genes = set([MPO_new.genes[n] for n in MPO_new.term_2_gene[node]])
    print(orig_genes.intersection(new_genes))
    print(orig_genes.union(new_genes))
    print("Original ", orig_genes.difference(new_genes))
    print("new ", new_genes.difference(orig_genes))
    print("\n")
# Out:
# MP:0002069
# set()
# set()
# Original  set()
# new  set()
#
#
# MP:0001422
# {'NEUROD4', 'SCT', 'UCN2', 'PTGS1', 'OXT', 'SCTR', 'TRPV4', 'PTGS2'}
# {'NEUROD4', 'SCT', 'UCN2', 'PTGS1', 'OXT', 'SCTR', 'TRPV4', 'PTGS2'}
# Original  set()
# new  set()
#
#
# MP:0001423
# {'ITPR3', 'NOS1', 'POU2F3', 'SLC18A2', 'DISC1', 'BDNF', 'EHMT1', 'ACADS', 'ADORA2A'}
# {'NOS1', 'EHMT2', 'ACADS', 'ADORA2A', 'ITPR3', 'POU2F3', 'SLC18A2', 'GRIN1', 'DISC1', 'BDNF', 'EHMT1'}
# Original  set()
# new  {'EHMT2', 'GRIN1'}
#
#
# MP:0001987
# {'SLC29A1', 'FAAH', 'CCL2', 'SLC6A1', 'EPS8', 'UNC79', 'CRHR1', 'TRPV1', 'GPR26', 'GABRB1', 'PRKCG'}
# {'SLC29A1', 'FAAH', 'CCR2', 'SLC6A1', 'LINC02210-CRHR1', 'EPS8', 'TRPV1', 'GPR26', 'CCL2', 'CCL8', 'UNC79', 'CRHR1', 'GABRB1', 'PRKCG'}
# Original  set()
# new  {'CCR2', 'LINC02210-CRHR1', 'CCL8'}
#
#
# MP:0002119
# set()
# set()
# Original  set()
# new  set()
#
#
# MP:0002570
# {'CCL2', 'CCR2', 'CACNA1B', 'DRD2', 'NPY2R', 'CCL3', 'MPDZ'}
# {'CCL3L1', 'CCR2', 'CCL3L3', 'MPDZ', 'CCL18', 'CCL2', 'CCL8', 'DRD2', 'NPY2R', 'CCL3', 'CACNA1B'}
# Original  set()
# new  {'CCL18', 'CCL3L1', 'CCL3L3', 'CCL8'}
#
#
# MP:0020379
# set()
# set()
# Original  set()
# new  set()
#
#
# MP:0001425
# {'POMC', 'PPP1R1B'}
# {'POMC', 'PPP1R1B'}
# Original  set()
# new  set()
#
#
# MP:0003545
# {'NOS1', 'SLC29A1', 'FAAH', 'CCL2', 'CCR2', 'GRIN1', 'ALK', 'POMC', 'EPS8', 'CCR5', 'SLC6A1', 'TAOK2', 'UNC79', 'TRPV1', 'NPY1R'}
# {'NOS1', 'SLC29A1', 'FAAH', 'CCR2', 'POMC', 'ALK', 'SLC6A1', 'EPS8', 'TAOK2', 'TRPV1', 'CCL2', 'GRIN1', 'CCR5', 'UNC79', 'CCL8', 'NPY1R'}
# Original  set()
# new  {'CCL8'}
#
#
# MP:0003546
# {'GRIA3', 'ALDH2', 'CCL2', 'CCR2', 'GRIN1', 'GNAS', 'SLC18A2', 'MPDZ', 'CACNA1B', 'DRD2', 'CCL3', 'GRM5', 'DRD3'}
# {'GRIA3', 'CCL3L1', 'PRKCE', 'ALDH2', 'CCR2', 'GNAS', 'CACNA1B', 'CCL3L3', 'MPDZ', 'CCL18', 'CCL2', 'SLC18A2', 'GRIN1', 'CCL8', 'DRD2', 'CCL3', 'GRM5', 'DRD3'}
# Original  set()
# new  {'PRKCE', 'CCL8', 'CCL3L3', 'CCL3L1', 'CCL18'}
#
#
# MP:0012042
# set()
# set()
# Original  set()
# new  set()
#
#
# MP:0001428
# {'HAX1', 'TH', 'WLS'}
# {'TH', 'WLS', 'HAX1', 'DBH'}
# Original  set()
# new  {'DBH'}
#
#
# MP:0005111
# {'AGRP', 'CHRM5'}
# {'AGRP', 'CHRM5'}
# Original  set()
# new  set()
#
#
# MP:0011737
# {'MMP17', 'FMR1'}
# {'MMP17', 'FMR1'}
# Original  set()
# new  set()
#
#
# MP:0011947
# {'AGTR2', 'PROKR1'}
# {'AGTR2', 'PROKR1'}
# Original  set()
# new  set()
#
#
# MP:0011941
# {'GRN', 'VDR', 'CCR2', 'NEDD4L', 'TAOK2', 'PPARG', 'NR1H4', 'VAMP8', 'UMOD', 'UNC5C', 'DICER1', 'ITPR3', 'CTSA', 'AGT', 'CCL2', 'SLC14A1', 'HIF1AN', 'APRT', 'EPM2A', 'FOXA2', 'FXYD4', 'CCKBR', 'ACE', 'MTSS1', 'CCL3', 'NPY2R', 'DRD3', 'SCUBE3', 'MARK4', 'SLC5A2', 'ADCY6', 'AVP', 'NPY4R', 'SLC14A2', 'WNT10A', 'SLC16A10', 'SYNM', 'CHRM3', 'AGPAT2', 'AGTR2', 'HTR1B', 'TGFB1', 'CCR5', 'UNC79', 'COL4A4', 'DRD2', 'GFRA2', 'APOE', 'GDF15', 'MCHR1'}
# {'VDR', 'CCR2', 'NEDD4L', 'TAOK2', 'PPARG', 'NR1H4', 'PAX8', 'DICER1', 'CTSA', 'CCL2', 'HIF1AN', 'APRT', 'FXYD4', 'NPY2R', 'MTSS1', 'INS', 'DRD3', 'SCUBE3', 'SLC5A2', 'SCD', 'LEPR', 'CCL3L3', 'SLC14A2', 'SYNM', 'AGTR2', 'SCD5', 'TGFB1', 'UNC79', 'INS-IGF2', 'APOE', 'GRN', 'AGTR1', 'VAMP8', 'UMOD', 'UNC5C', 'CCL18', 'ITPR3', 'AGT', 'SLC14A1', 'SENP1', 'EPM2A', 'FOXA2', 'CCKBR', 'ACE', 'CCL3', 'MARK4', 'ADCY6', 'AVP', 'NPY4R', 'WNT10A', 'SLC16A10', 'CHRM3', 'GLA', 'AGPAT2', 'HTR1B', 'CCR5', 'CCL8', 'COL4A4', 'DRD2', 'GFRA2', 'LEP', 'GDF15', 'CCL3L1', 'MCHR1'}
# Original  set()
# new  {'CCL3L1', 'GLA', 'AGTR1', 'SENP1', 'SCD5', 'CCL8', 'SCD', 'LEPR', 'CCL3L3', 'INS-IGF2', 'LEP', 'INS', 'PAX8', 'CCL18'}
#
#
# MP:0001426
# {'GRN', 'CRH', 'CLN3', 'CDK4', 'AQP2', 'SLC2A9', 'AQP3', 'PSAP', 'MANF', 'SCTR', 'TRPV5', 'INSR', 'NPR3', 'AGT', 'ATP6V0A4', 'LCLAT1', 'SIX2', 'PDSS2', 'FGF10', 'AVPR2', 'NOS1', 'UOX', 'NOS2', 'KCNJ1', 'FGFR1', 'CLDN10', 'LEPR', 'SLC12A1', 'IRS2', 'AFMID', 'GLIS2', 'AGPAT2', 'SIRT1', 'CD63', 'SCARB2', 'CEP290'}
# {'CRH', 'AQP2', 'MIR375', 'NPR3', 'AKR1B1', 'PDSS2', 'INS', 'AVPR2', 'NOS1', 'LEPR', 'CLDN10', 'SLC12A1', 'HPRT1', 'AFMID', 'GLIS2', 'NOS3', 'INS-IGF2', 'SCARB2', 'CEP290', 'GRN', 'CLN3', 'CDK4', 'SLC2A9', 'AQP3', 'MOGAT1', 'PSAP', 'MANF', 'SCTR', 'TRPV5', 'INSR', 'AGT', 'ATP6V0A4', 'LCLAT1', 'REN', 'SIX2', 'FGF10', 'UOX', 'NOS2', 'KCNJ1', 'FGFR1', 'FGFR2', 'IRS2', 'AGPAT2', 'PPP2R2A', 'SIRT1', 'CD63', 'HNF4A', 'LEP'}
# Original  {'MIR375'}
# new  {'HPRT1', 'NOS3', 'MOGAT1', 'PPP2R2A', 'AKR1B1', 'REN', 'INS-IGF2', 'HNF4A', 'LEP', 'INS', 'FGFR2'}
#
#
# MP:0011942
# {'TRIM37', 'MMP17', 'PTGER1', 'PHOSPHO1', 'TRIB2', 'APLNR', 'BRS3', 'OPN3', 'ARHGAP17', 'TRPV4', 'STUB1', 'ADM', 'CISD2', 'TRPV1', 'CYP11B2', 'GABRA5', 'STK11', 'DRD2', 'DNAJC30', 'HNF4G', 'MYH1'}
# {'TRIM37', 'MMP17', 'PTGER1', 'PHOSPHO1', 'TRIB2', 'APLNR', 'BRS3', 'OPN3', 'ARHGAP17', 'TRPV4', 'STUB1', 'ADM', 'CISD2', 'CYP11B1', 'TRPV1', 'CYP11B2', 'GABRA5', 'STK11', 'DRD2', 'DNAJC30', 'HNF4G', 'MYH1'}
# Original  set()
# new  {'CYP11B1'}
#
#
# MP:0011948
# set()
# set()
# Original  set()
# new  set()
#
#
# MP:0011949
# set()
# set()
# Original  set()
# new  set()
#
#
# MP:0011950
# set()
# set()
# Original  set()
# new  set()
#
#
# MP:0001431
# {'CACNA2D2', 'GPD2', 'LEP', 'PDYN', 'GNAS', 'TARDBP', 'HAP1', 'LRRC4B', 'CLOCK', 'ATP8A2', 'BBS12', 'MBOAT7', 'MAOA', 'BRD2', 'FOXP2', 'RUNX3', 'EIF2AK4', 'GHRHR', 'CCKAR', 'FTO', 'GRIN1', 'GTF2IRD1', 'MARK2', 'NFIC', 'HSD11B1', 'TLR5', 'AGRP', 'WFS1', 'NPY2R', 'CCKBR', 'NCOA3', 'STAT3', 'DBH', 'ZEB1', 'KLB', 'MGLL', 'MC3R', 'ERRFI1', 'SLC34A1', 'NOS2', 'NTF3', 'ACOT13', 'GATM', 'ADGRL3', 'HDAC4', 'NPY4R', 'LEPR', 'PSMC1', 'GPSM1', 'PNRC2', 'ZFHX3', 'FASN', 'NCOR2', 'GLB1', 'IGF2BP1', 'CSF1', 'APBA2', 'DUSP1', 'AGTR2', 'CRHR2', 'MCAT', 'SCNN1A', 'NR2C2', 'OTC', 'SIK3', 'DRD2', 'PTPRD', 'JAG1', 'MAF', 'PEX7', 'NPY1R', 'IGFBP3', 'TOR1A'}
# {'CACNA2D2', 'PDYN', 'CES1', 'MBOAT7', 'GHRHR', 'MARK2', 'HSD11B1', 'WFS1', 'NCOA3', 'MC3R', 'NAA40', 'ACOT13', 'RMI1', 'SCD', 'LEPR', 'PSMC1', 'ZFHX3', 'IGF2BP1', 'APBA2', 'SCD5', 'JAG1', 'TOR1A', 'MAOA', 'PRLR', 'RUNX3', 'DRD1', 'EIF2AK4', 'GRIN1', 'CCKBR', 'SLC17A6', 'ERRFI1', 'SLC34A1', 'NOS2', 'GATM', 'ASIP', 'NPY4R', 'TH', 'PNRC2', 'GLB1', 'OTC', 'DRD2', 'LEP', 'NPY1R', 'IGFBP3', 'GPD2', 'GNAS', 'TARDBP', 'HAP1', 'ATP8A2', 'BRD2', 'FOXP2', 'FTO', 'NFIC', 'TLR5', 'AGRP', 'NPY2R', 'STAT3', 'ADGRL3', 'TPH2', 'PTPN2', 'GPSM1', 'CSF1', 'AGTR2', 'MCAT', 'SCNN1A', 'NR2C2', 'SIK3', 'PTPRD', 'MAF', 'LRRC4B', 'BBS12', 'GTF2IRD1', 'H2AZ2', 'DBH', 'ZEB1', 'KLB', 'MGLL', 'NTF3', 'HDAC4', 'FASN', 'NCOR2', 'DUSP1', 'CRHR2', 'PTPN1', 'PEX7', 'CLOCK', 'CCKAR'}
# Original  set()
# new  {'SLC17A6', 'DRD1', 'H2AZ2', 'NAA40', 'SCD5', 'ASIP', 'RMI1', 'SCD', 'TPH2', 'PTPN2', 'TH', 'PTPN1', 'CES1', 'PRLR'}
#
#
# MP:0001432
# {'PRLHR', 'EIF2AK4', 'PER2', 'FEZF2', 'CD36', 'HDAC4', 'PER1', 'CSK', 'BCAT2', 'OXT', 'RXFP4', 'ACADS'}
# {'PRLHR', 'PER2', 'HDAC4', 'CSK', 'RXFP4', 'ACADS', 'EIF2AK4', 'FEZF2', 'CD36', 'PER1', 'BCAT2', 'OXT'}
# Original  set()
# new  set()
#
#
# MP:0011976
# {'GPR83'}
# {'GPR83'}
# Original  set()
# new  set()
#
#
# MP:0002850
# {'UNC79', 'SLC6A1'}
# {'UNC79', 'SLC6A1'}
# Original  set()
# new  set()
#
#
# MP:0012308
# set()
# set()
# Original  set()
# new  set()
#
#
# MP:0012347
# {'ITPR3', 'ATP2B1', 'DISC1'}
# {'ITPR3', 'ATP2B1', 'DISC1'}
# Original  set()
# new  set()
#
#
# MP:0031056
# set()
# set()
# Original  set()
# new  set()
#
#
# MP:0031057
# set()
# set()
# Original  set()
# new  set()
#
#
# MP:0001436
# {'WNT3A', 'SNRPN', 'PPP1R15B', 'RLN1', 'NR4A2', 'DHCR7', 'GNB1', 'ACVR1', 'CHRNA7', 'SEC23B', 'COPB2', 'HSD17B4', 'GRM7', 'GK', 'GJA1', 'PROC', 'GAD1', 'MMUT', 'EIF2S1', 'PIGA', 'BIN1', 'EHMT1', 'TOR1A', 'FOXG1', 'TASP1', 'GNAL', 'SALL1', 'FGF9', 'NEUROD6', 'MAGEL2', 'HOXA1', 'HRAS', 'PHF21A', 'CPEB4', 'GPHN', 'CCND1', 'BMPR1A', 'GRIN1', 'KCNJ2', 'CDKN1C', 'DPP9', 'CFL2', 'MYH10', 'SLC27A4', 'TGFB3', 'STRADA', 'ZDHHC16', 'ELP1', 'GSC', 'LGR5', 'DNM1', 'NEUROG1', 'DGAT2', 'PEX11B', 'BCL11B', 'DLX5', 'HSD11B2', 'NEUROG2', 'GNAS', 'UBR3', 'HAP1', 'FKBP8', 'SPAG17', 'FOXF2', 'DACH1', 'OGT', 'SLC6A9', 'MAPK6', 'CDC42', 'JAK1', 'KIF2A', 'SYT1', 'EN1', 'HELT', 'FYN', 'LOX', 'PPME1', 'CRLF1', 'PLEC', 'FUS', 'ZIC1', 'GTF2A1', 'KLF4', 'CYS1', 'HOXA2', 'TGM1', 'POU2F2', 'SYNGAP1', 'GRIN2B', 'PROX1', 'ILF3', 'DLX2', 'HAND2', 'CASK', 'NEB', 'DCC', 'MARCKS', 'LPAR1', 'ZEB1', 'LMX1B', 'NTF3', 'GRID2', 'LMNA', 'CHRNG', 'MN1', 'ARAF', 'SALL3'}
# {'WNT3A', 'SNRPN', 'PPP1R15B', 'RLN1', 'NR4A2', 'DHCR7', 'GNB1', 'ACVR1', 'CHRNA7', 'SEC23B', 'COPB2', 'HSD17B4', 'GJA6P', 'GRM7', 'CCND3', 'GK', 'CHD7', 'GJA1', 'PROC', 'GAD1', 'RBPJ', 'MMUT', 'EIF2S1', 'PIGA', 'BIN1', 'EHMT1', 'TOR1A', 'FOXG1', 'TASP1', 'GNAL', 'SALL1', 'REG1A', 'FGF9', 'NEUROD6', 'MAGEL2', 'HOXA1', 'HRAS', 'PHF21A', 'CPEB4', 'GPHN', 'CCND1', 'BMPR1A', 'GRIN1', 'KCNJ2', 'EMX1', 'CDKN1C', 'DPP9', 'CFL2', 'MYH10', 'SLC27A4', 'TGFB3', 'STRADA', 'ZDHHC16', 'ELP1', 'GSC', 'LGR5', 'DNM1', 'TUBA8', 'NEUROG1', 'DGAT2', 'PEX11B', 'BCL11B', 'DLX5', 'SMN2', 'HSD11B2', 'NEUROG2', 'GNAS', 'HAP1', 'FKBP8', 'SPAG17', 'FOXF2', 'DACH1', 'UBR3', 'OGT', 'SLC6A9', 'MAPK6', 'CDC42', 'JAK1', 'KIF2A', 'INSL4', 'SYT1', 'EN1', 'HELT', 'SMN1', 'FYN', 'LOX', 'PPME1', 'CRLF1', 'PLEC', 'FUS', 'ZIC1', 'GTF2A1', 'KLF4', 'ATG5', 'CTNNB1', 'CYS1', 'HOXA2', 'TGM1', 'POU2F2', 'SYNGAP1', 'GRIN2B', 'PROX1', 'ILF3', 'DLX2', 'HAND2', 'ATRX', 'CASK', 'NEB', 'DCC', 'MARCKS', 'LPAR1', 'EHHADH', 'H2AZ2', 'ZEB1', 'RLN2', 'LMX1B', 'NTF3', 'GRID2', 'LMNA', 'CHRFAM7A', 'CHRNG', 'MN1', 'ARAF', 'SALL3', 'REG1B'}
# Original  set()
# new  {'RBPJ', 'ATG5', 'CHD7', 'RLN2', 'SMN2', 'SMN1', 'CTNNB1', 'H2AZ2', 'REG1B', 'INSL4', 'GJA6P', 'EMX1', 'REG1A', 'TUBA8', 'EHHADH', 'ATRX', 'CHRFAM7A', 'CCND3'}
#
#
# MP:0001437
# {'NTRK2', 'DHCR7', 'PTS', 'NR2F1'}
# {'NR2F1', 'DHCR7', 'NTRK2', 'PTS'}
# Original  set()
# new  set()
#
#
# MP:0020863
# set()
# set()
# Original  set()
# new  set()
#
#
# MP:0001435
# {'INHBA', 'CLCF1', 'KCNJ13', 'DYNC1H1', 'POU4F1', 'CNTFR', 'CDK5', 'GRIN1', 'IGF2R', 'ABCA12', 'SLC27A4', 'DHCR7', 'HAND2', 'NTRK2', 'GRIN2B'}
# {'INHBA', 'CLCF1', 'DYNC1H1', 'POU4F1', 'CDK5', 'IGF2R', 'SLC27A4', 'DHCR7', 'HAND2', 'NTRK2', 'CNTFR', 'KCNJ13', 'GRIN1', 'ABCA12', 'GRIN2B'}
# Original  set()
# new  set()
#
#
# MP:0020864
# {'SHANK3'}
# {'SHANK3'}
# Original  set()
# new  set()
#
#
# MP:0020865
# set()
# set()
# Original  set()
# new  set()
#
#
# MP:0005449
# {'CRH', 'ME1', 'E2F4', 'PSAP', 'IL1R1', 'CARTPT', 'GIGYF2', 'CLOCK', 'MC4R', 'TNF', 'SLC17A7', 'NPY6R', 'RXFP4', 'JPH3', 'ITPR3', 'NMUR2', 'PRKAR2B', 'SDC3', 'BRS3', 'RSC1A1', 'GRIN1', 'IL6', 'CIBAR1', 'CNR1', 'AGRP', 'CRHR1', 'HSD11B1', 'NPY2R', 'NFKB2', 'OXT', 'NOX3', 'ITGA11', 'CCDC80', 'DBH', 'HTR4', 'DRD3', 'MC3R', 'ASL', 'ACSS1', 'ATP1B2', 'SCUBE3', 'CFL2', 'PER2', 'CRHBP', 'NTF3', 'GRPR', 'SH3KBP1', 'NPY4R', 'LEPR', 'FGF21', 'PITX3', 'KCNJ11', 'SCP2', 'IGHMBP2', 'GHRL', 'GBA', 'GHSR', 'CBL', 'CRHR2', 'DNAJC3', 'GHR', 'GLP1R', 'CD36', 'BSX', 'UCP2', 'PER1', 'GLUL', 'WASF1', 'PTPN1', 'LEP', 'GFRAL', 'DMBX1', 'CCKAR'}
# {'MC4R', 'TNF', 'NPY6R', 'SLC17A7', 'JPH3', 'SDC3', 'RSC1A1', 'HSD11B1', 'CRHR1', 'NOX3', 'HTR4', 'DRD3', 'MC3R', 'SCUBE3', 'ACSS1', 'LEPR', 'GHRL', 'GHR', 'PSAP', 'IL1R1', 'CARTPT', 'SOCS3', 'NMUR2', 'GRIN1', 'IL6', 'CNR1', 'LDLR', 'ASL', 'CFL2', 'PER2', 'LINC02210-CRHR1', 'ASIP', 'SH3KBP1', 'NPY4R', 'PITX3', 'DNAJC3', 'UCP2', 'GLUL', 'LEP', 'CRH', 'E2F4', 'TARDBP', 'SLC32A1', 'RXFP4', 'CIBAR1', 'AGRP', 'NPY2R', 'ITGA11', 'CCDC80', 'CRHBP', 'GRPR', 'SCP2', 'KCNJ11', 'GBA', 'GHSR', 'CBL', 'GLP1R', 'CD36', 'BSX', 'PER1', 'WASF1', 'GFRAL', 'DMBX1', 'ME1', 'GIGYF2', 'JPH4', 'ITPR3', 'PRKAR2B', 'BRS3', 'NFKB2', 'OXT', 'DBH', 'KLB', 'ATP1B2', 'NTF3', 'FGF21', 'SNORD116', 'IGHMBP2', 'ITPR2', 'CRHR2', 'PTPN1', 'ZNF423', 'CLOCK', 'CCKAR'}
# Original  {'SNORD116'}
# new  {'ITPR2', 'LINC02210-CRHR1', 'ASIP', 'TARDBP', 'SLC32A1', 'KLB', 'LDLR', 'JPH4', 'ZNF423', 'SOCS3'}
#
#
# MP:0001438
# {'PAX9', 'OLIG2', 'PRRX1', 'EVC', 'EPS15L1', 'SLC4A2', 'ZMPSTE24', 'ITGB4', 'LGI1', 'UBA6', 'GRIN1', 'ILK', 'EN1', 'SOCS7', 'DBH', 'DYNC1H1', 'POU4F1', 'PEX13', 'PEX2', 'CASR', 'TCF15', 'TH', 'ACAN', 'PRX', 'TBR1', 'GBA', 'ROBO1', 'HOXA2', 'HAX1', 'FOXD1', 'CFTR', 'DRD2', 'PRRX2', 'TGM1', 'RFX6', 'LAMC2', 'TSHZ1'}
# {'OLIG2', 'EVC', 'SLC4A2', 'ITGB4', 'LGI1', 'UBA6', 'EN1', 'PEX13', 'PEX2', 'ACAN', 'GBA', 'ROBO1', 'HOXA2', 'FOXD1', 'CFTR', 'TGM1', 'ACD', 'RFX6', 'PAX9', 'LAMC2', 'TSHZ1', 'PRRX1', 'EPS15L1', 'RNF165', 'ZMPSTE24', 'DRD1', 'GRIN1', 'ILK', 'SOCS7', 'H2AZ2', 'DBH', 'DYNC1H1', 'POU4F1', 'CASR', 'TCF15', 'TH', 'PRX', 'TBR1', 'HAX1', 'DRD2', 'PRRX2'}
# Original  set()
# new  {'H2AZ2', 'DRD1', 'RNF165', 'ACD'}
#
#
# MP:0009546
# {'SNRPN', 'EZH1', 'RLN1', 'PGAP1', 'DHCR7', 'TLX3', 'SH3GL2', 'GSX2', 'CERS3', 'CEBPA', 'ATP6V0A1', 'SLC23A1', 'GAD1', 'DMTF1', 'BCLAF1', 'MMUT', 'GNE', 'PKDCC', 'SLC18A2', 'PSIP1', 'UNC79', 'SH3PXD2A', 'DNM3', 'EHMT1', 'TOR1A', 'FOXG1', 'EPS15L1', 'HOXC4', 'FGFR3', 'IRX1', 'SRSF5', 'MAGEL2', 'DMRTA2', 'USP7', 'SCYL2', 'CPEB4', 'SNAP29', 'GRIN1', 'CDKN1C', 'ISL1', 'SPIN1', 'DPP9', 'ERRFI1', 'POU4F1', 'DLG1', 'SLC27A4', 'TGFB3', 'SPINT1', 'ALX4', 'ELP1', 'GSC', 'ARFGEF1', 'KRT5', 'LGR5', 'ASCL1', 'DRD2', 'MSX1', 'BCL11B', 'TRIO', 'DLX5', 'GNAS', 'HAP1', 'NTN1', 'SPAG17', 'FOXF2', 'DACH1', 'MSX2', 'SLC6A9', 'CDC42', 'KIF13B', 'PNPLA1', 'EN1', 'FSCN1', 'PDSS2', 'APLP2', 'CEP55', 'SCN2A', 'USF2', 'SYNE1', 'CRLF1', 'DNM1L', 'RUNX1T1', 'DERL2', 'ATG5', 'CYP1A2', 'GBA', 'ROBO1', 'GRB2', 'JPH1', 'KLF7', 'ESRRG', 'GRIN2B', 'DMBX1', 'PCK1', 'TCF7L2', 'ALX1', 'PEG3', 'DHRS3', 'ST14', 'G0S2', 'BRINP1', 'ATF5', 'FBXL12', 'PRTG', 'MNT', 'PIP5K1C', 'PCCA', 'GRID2', 'SH2D3C', 'AFAP1', 'UNC13A', 'SAFB', 'MRAP'}
# {'SNRPN', 'EZH1', 'RLN1', 'PGAP1', 'DHCR7', 'TLX3', 'SH3GL2', 'GSX2', 'TP63', 'CERS3', 'CEBPA', 'ATP6V0A1', 'SLC23A1', 'GAD1', 'DMTF1', 'BCLAF1', 'SH3GL1', 'MMUT', 'GNE', 'PKDCC', 'SLC18A2', 'PSIP1', 'UNC79', 'SH3PXD2A', 'DNM3', 'EHMT1', 'TOR1A', 'FOXG1', 'EPS15L1', 'HOXC4', 'FGFR3', 'VEGFA', 'IRX1', 'SRSF5', 'MAGEL2', 'DMRTA2', 'USP7', 'SCYL2', 'CPEB4', 'DRD1', 'SNAP29', 'GRIN1', 'CDKN1C', 'ISL1', 'SPIN1', 'DPP9', 'ERRFI1', 'POU4F1', 'DLG1', 'SLC27A4', 'TGFB3', 'SPINT1', 'ALX4', 'ELP1', 'NEURL1', 'GSC', 'ARFGEF1', 'KRT5', 'LGR5', 'ALX3', 'DNM1', 'ASCL1', 'DRD2', 'MSX1', 'BCL11B', 'TRIO', 'DLX5', 'RSPO2', 'GNAS', 'HAP1', 'NTN1', 'SPAG17', 'FOXF2', 'DACH1', 'MSX2', 'SLC6A9', 'CDC42', 'KIF13B', 'PNPLA1', 'INSL4', 'EN1', 'EZH2', 'FSCN1', 'PDSS2', 'SH3GL3', 'APLP2', 'BRSK2', 'CEP55', 'SCN2A', 'APP', 'USF2', 'SYNE1', 'CRLF1', 'ALPL', 'DNM1L', 'MYF5', 'RUNX1T1', 'DERL2', 'ATG5', 'CYP1A2', 'GBA', 'ROBO1', 'GRB2', 'JPH1', 'KLF7', 'ESRRG', 'GRIN2B', 'DMBX1', 'PCK1', 'TCF7L2', 'ALX1', 'PEG3', 'DHRS3', 'ST14', 'RSPO3', 'ATRX', 'TGFBR2', 'G0S2', 'RAPH1', 'KIF13A', 'BRINP1', 'ATF5', 'FBXL12', 'PRTG', 'MNT', 'PIP5K1C', 'RLN2', 'PCCA', 'GRID2', 'SH2D3C', 'AFAP1', 'UNC13A', 'SAFB', 'MRAP', 'ROBO2'}
# Original  set()
# new  {'RSPO2', 'VEGFA', 'RSPO3', 'ATRX', 'TGFBR2', 'RAPH1', 'DRD1', 'KIF13A', 'INSL4', 'EZH2', 'SH3GL3', 'TP63', 'BRSK2', 'RLN2', 'APP', 'ALPL', 'MYF5', 'SH3GL1', 'NEURL1', 'ALX3', 'DNM1', 'ROBO2'}
#
#
# MP:0002849
# {'UNC79'}
# {'UNC79'}
# Original  set()
# new  set()
#
#
# MP:0003158
# {'IGHMBP2', 'UCHL1', 'CDKN1C', 'COL19A1', 'PDSS2', 'LDB3'}
# {'IGHMBP2', 'PDSS2', 'UCHL3', 'UCHL1', 'MOB1B', 'CDKN1C', 'COL19A1', 'LDB3', 'MOB1A'}
# Original  set()
# new  {'UCHL3', 'MOB1B', 'MOB1A'}
#
#
# MP:0011939
# {'CSF2', 'SLURP1', 'TAFA1', 'NR1H4', 'MC4R', 'BBS1', 'NPY6R', 'HSD11B1', 'FXYD4', 'BCAT2', 'TNKS', 'DRD3', 'OTP', 'CEBPA', 'SLC5A2', 'ACOT13', 'LEPR', 'APOA4', 'SQSTM1', 'ACER1', 'C1QTNF9', 'HRH1', 'LIPA', 'GHR', 'HTR2C', 'PRLH', 'CIDEC', 'FMO5', 'VEGFD', 'UMOD', 'APMAP', 'TMEM18', 'LIPE', 'ACE', 'CCKBR', 'ITPRID2', 'LDLR', 'C5AR2', 'PTTG1', 'MRAP2', 'NOS2', 'FFAR1', 'GLP2R', 'FOLH1', 'CYB5R4', 'ARID5B', 'SIRT7', 'ATP2B1', 'DRD2', 'LEP', 'BBIP1', 'GDF15', 'APOE', 'SNAP25', 'MCHR1', 'POMC', 'GNAS', 'TUB', 'ARV1', 'HILPDA', 'ROCK1', 'FTO', 'PLIN1', 'HIF1AN', 'ALDH3A2', 'AGRP', 'SLC25A25', 'CCDC80', 'ATM', 'NOS1', 'PDPK1', 'ALMS1', 'LMTK3', 'RAI1', 'NUCKS1', 'ACOT11', 'BBS7', 'GPR61', 'TGFB1', 'APOC3', 'TLR2', 'MSTN', 'ADIPOQ', 'ADIPOR2', 'GRN', 'PLEKHN1', 'ACTB', 'NCOR1', 'CDO1', 'BECN2', 'PRKCI', 'UNC5C', 'OSMR', 'MBOAT4', 'CDKN1A', 'BRS3', 'PMCH', 'FOXA2', 'DBH', 'GPR50', 'ZEB1', 'BSCL2', 'PPP1R3G', 'HDAC4', 'GPR26', 'SGK3', 'AGPAT2', 'SIRT1', 'GFRA2', 'CAV1'}
# {'CSF2', 'SLURP1', 'C8orf44-SGK3', 'RNF213', 'TAFA1', 'NR1H4', 'MC4R', 'BBS1', 'NPY6R', 'HSD11B1', 'FXYD4', 'BCAT2', 'TNKS', 'DRD3', 'OTP', 'CEBPA', 'SLC5A2', 'ACOT13', 'SCD', 'LEPR', 'APOA4', 'SQSTM1', 'ACER1', 'C1QTNF9', 'HRH1', 'LIPA', 'DGAT1', 'GHR', 'HTR2C', 'SCD5', 'PRLH', 'CIDEC', 'PTTG3P', 'FMO5', 'VEGFD', 'UMOD', 'APMAP', 'TMEM18', 'LIPE', 'C1QTNF9B', 'ACE', 'CCKBR', 'ITPRID2', 'LDLR', 'C5AR2', 'SLC17A6', 'PTTG1', 'MRAP2', 'NOS2', 'SLC5A1', 'ASIP', 'FFAR1', 'TH', 'GLP2R', 'FOLH1', 'CYB5R4', 'ARID5B', 'SIRT7', 'ATP2B1', 'FOLH1B', 'DRD2', 'LEP', 'BBIP1', 'GDF15', 'APOE', 'SNAP25', 'MCHR1', 'PMCHL2', 'POMC', 'GNAS', 'ATG12', 'TUB', 'ARV1', 'HILPDA', 'ROCK1', 'FTO', 'PLIN1', 'HIF1AN', 'ALDH3A2', 'AGRP', 'SLC25A25', 'CCDC80', 'INS', 'ATM', 'NOS1', 'PDPK1', 'ALMS1', 'LMTK3', 'RAI1', 'NUCKS1', 'ACOT11', 'GABRB3', 'BBS7', 'GPR61', 'TGFB1', 'APOC3', 'TLR2', 'MSTN', 'ADIPOQ', 'INS-IGF2', 'ADIPOR2', 'GRN', 'PLEKHN1', 'ACTB', 'NCOR1', 'MOGAT1', 'CDO1', 'BECN2', 'PRKCI', 'UNC5C', 'LRP1', 'OSMR', 'MBOAT4', 'CDKN1A', 'BRS3', 'PMCH', 'FOXA2', 'PTTG2', 'IRS4', 'DBH', 'GPR50', 'ZEB1', 'CDKN1B', 'BSCL2', 'PPP1R3G', 'PDPK2P', 'HDAC4', 'CCDC7', 'GPR26', 'IRS2', 'SGK3', 'AGPAT2', 'SIRT1', 'SEL1L', 'GFRA2', 'CAV1'}
# Original  set()
# new  {'PMCHL2', 'PTTG3P', 'MOGAT1', 'C8orf44-SGK3', 'RNF213', 'ATG12', 'LRP1', 'C1QTNF9B', 'PTTG2', 'INS', 'IRS4', 'CDKN1B', 'SLC17A6', 'SLC5A1', 'ASIP', 'PDPK2P', 'SCD', 'TH', 'CCDC7', 'IRS2', 'GABRB3', 'DGAT1', 'SCD5', 'FOLH1B', 'SEL1L', 'INS-IGF2'}
#
#
# MP:0001433
# {'CLPS', 'CLIC5', 'BBS2', 'ARNT2', 'CPE', 'CRTC1', 'PLEKHN1', 'POMC', 'SCG5', 'PPARG', 'TARDBP', 'MC4R', 'HRH3', 'SLC32A1', 'PRKAG2', 'TLR4', 'SIM1', 'ANKRD26', 'PRKAR2B', 'INSR', 'SDC3', 'BRS3', 'NTSR1', 'FTO', 'LCLAT1', 'ADRB3', 'TLR5', 'NPY5R', 'EPM2A', 'PANK1', 'NMU', 'NPY2R', 'NPBWR1', 'BDNF', 'PYY', 'CLTRN', 'HNF1A', 'ACACB', 'MARK4', 'MRAP2', 'BSCL2', 'PCSK1', 'CEP19', 'STAT5B', 'PIK3CA', 'LEPR', 'RAI1', 'C3', 'NHLH2', 'IRS2', 'BBS4', 'IL18', 'GPR61', 'BBS10', 'CBL', 'HTR2C', 'SIRT1', 'BSX', 'GUCY2C', 'MPZL3', 'LEP', 'ATE1', 'BBIP1', 'GFRAL', 'MCHR1', 'TCF7L2'}
# {'ARNT2', 'CEACAM8', 'MC4R', 'PSG2', 'PRKAG2', 'PSG11', 'SDC3', 'PSG6', 'CEACAM6', 'NPY5R', 'CEACAM5', 'NPBWR1', 'BDNF', 'ACACB', 'SCD', 'LEPR', 'CEACAM21', 'HTR2C', 'SCD5', 'ATE1', 'BBS4', 'BBS2', 'PSG3', 'INSR', 'CEACAM3', 'NTSR1', 'CLTRN', 'SLC17A6', 'MARK4', 'MRAP2', 'PCSK1', 'STAT5B', 'ASIP', 'C3', 'PSG5', 'LEP', 'BBIP1', 'MCHR1', 'GUCY2C', 'CPE', 'CRTC1', 'POMC', 'PPARG', 'TARDBP', 'HRH3', 'SLC32A1', 'ANKRD26', 'FTO', 'TLR5', 'NMU', 'NPY2R', 'PYY', 'PSG9', 'INS', 'STAT3', 'PSG8', 'PDPK1', 'CEP19', 'RAI1', 'NHLH2', 'GPR61', 'BBS10', 'CBL', 'CEACAM4', 'BSX', 'INS-IGF2', 'CEACAM1', 'GFRAL', 'TCF7L2', 'CLPS', 'CLIC5', 'PLEKHN1', 'SCG5', 'PSG1', 'TLR4', 'SIM1', 'PYY3', 'PRKAR2B', 'ANKRD62', 'BRS3', 'LCLAT1', 'ADRB3', 'EPM2A', 'PANK1', 'HNF1A', 'CDKN1B', 'PSG4', 'BSCL2', 'PDPK2P', 'PIK3CA', 'SNORD116', 'CEACAM7', 'IRS2', 'IL18', 'SIRT1', 'STAT5A', 'MPZL3'}
# Original  {'SNORD116'}
# new  {'CEACAM8', 'PSG3', 'PSG1', 'PSG2', 'PYY3', 'PSG11', 'ANKRD62', 'CEACAM3', 'PSG6', 'CEACAM6', 'CEACAM5', 'PSG9', 'STAT3', 'INS', 'CDKN1B', 'PSG8', 'SLC17A6', 'PSG4', 'PDPK1', 'ASIP', 'PDPK2P', 'SCD', 'CEACAM7', 'CEACAM21', 'SCD5', 'CEACAM4', 'PSG5', 'STAT5A', 'INS-IGF2', 'CEACAM1'}
#
#
# MP:0011958
# {'PRLH', 'P2RX7', 'MRAP2', 'PRKAA2', 'GUCY2C'}
# {'PRLH', 'P2RX7', 'MRAP2', 'PRKAA2', 'GUCY2C'}
# Original  set()
# new  set()
#
#
# MP:0011940
# {'ENHO', 'RAPGEF3', 'PLIN2', 'MAPK8', 'TRIM37', 'TAFA1', 'DLL1', 'LYPD3', 'NPY6R', 'ABHD6', 'SLC27A5', 'UCN2', 'NPY5R', 'PRCP', 'WFS1', 'CPT1C', 'CTF1', 'THRA', 'ENPP1', 'ULK4', 'PRLHR', 'FLNC', 'ACOT13', 'DBX1', 'RMI1', 'HRH1', 'GCGR', 'HTR2C', 'HNF4G', 'MYH1', 'MYLK', 'BRAF', 'RCAN2', 'PTGER1', 'SEMA3A', 'SLC30A7', 'NMUR2', 'NPFFR2', 'HTR6', 'IMPACT', 'HCN2', 'ALKBH7', 'SLN', 'CISD2', 'MAPK8IP1', 'SLC5A1', 'CXCL14', 'ARID5B', 'SIK2', 'DRD2', 'LEP', 'SNAP25', 'NPY1R', 'FBN1', 'POMC', 'CYP11A1', 'PPARG', 'MLXIPL', 'TNFRSF1A', 'VIPR2', 'NEGR1', 'PRKAB1', 'CIDEB', 'HILPDA', 'FTO', 'TNN', 'OPN3', 'EN1', 'NDUFA1', 'AGRP', 'C1QTNF5', 'KCTD1', 'CLDN12', 'BRPF1', 'SLC16A1', 'MAF1', 'ACBD5', 'SLC52A3', 'GHSR', 'GLP1R', 'ADIPOQ', 'DMBX1', 'CAMKK2', 'PDE10A', 'MYD88', 'ALK', 'SOD2', 'GPR82', 'PHOSPHO1', 'TRIB2', 'CTSD', 'CALCA', 'PMCH', 'PPARGC1A', 'DBH', 'EIF4B', 'FADS2', 'HDAC4', 'ATF3', 'CHRM3', 'CDKAL1', 'NPC1', 'ATN1', 'QRFP', 'PTPN1', 'FOXO6'}
# {'ENHO', 'RAPGEF3', 'PLIN2', 'MAPK8', 'TRIM37', 'TAFA1', 'DLL1', 'EN2', 'LYPD3', 'NPY6R', 'ABHD6', 'OR4M1', 'NEAT1', 'SLC27A5', 'UCN2', 'NPY5R', 'PRCP', 'WFS1', 'CPT1C', 'CTF1', 'ENPP1', 'THRA', 'ULK4', 'PRLHR', 'NFE2L2', 'FLNC', 'ACOT13', 'DBX1', 'RMI1', 'NDOR1', 'HRH1', 'GCGR', 'HTR2C', 'AUTS2', 'HNF4G', 'MYH1', 'MYLK', 'BRAF', 'RCAN2', 'PTGER1', 'SEMA3A', 'SLC30A7', 'NMUR2', 'OR4M2', 'NPFFR2', 'KRT6A', 'EMX1', 'MFRP', 'HTR6', 'IMPACT', 'HCN2', 'ALKBH7', 'SLN', 'CISD2', 'MAPK8IP1', 'SLC5A1', 'CXCL14', 'TH', 'TNFRSF1B', 'ARID5B', 'AKR1B15', 'SIK2', 'DRD2', 'LEP', 'SNAP25', 'NPY1R', 'PMCHL2', 'FBN1', 'POMC', 'CYP11A1', 'PPARG', 'HAP1', 'MLXIPL', 'TNFRSF1A', 'VIPR2', 'NEGR1', 'PRKAB1', 'CIDEB', 'HILPDA', 'FTO', 'TNN', 'OPN3', 'EN1', 'NDUFA1', 'AGRP', 'C1QTNF5', 'KCTD1', 'STAT3', 'CLDN12', 'BRPF1', 'SLC16A1', 'MAF1', 'ACBD5', 'SLC52A3', 'GHSR', 'GLP1R', 'ADIPOQ', 'TAGLN', 'DMBX1', 'CAMKK2', 'PDE10A', 'MYD88', 'ALK', 'SOD2', 'GPR82', 'PHOSPHO1', 'TRIB2', 'CTSD', 'CALCA', 'PMCH', 'PPARGC1A', 'DBH', 'EIF4B', 'FADS2', 'HDAC4', 'ATF3', 'CHRM3', 'CDKAL1', 'NPC1', 'AKR1B10', 'ATN1', 'QRFP', 'KRT6B', 'PTPN1', 'FOXO6'}
# Original  {'NEAT1'}
# new  {'NFE2L2', 'OR4M2', 'PMCHL2', 'AKR1B10', 'TNFRSF1B', 'KRT6A', 'KRT6B', 'EMX1', 'MFRP', 'AKR1B15', 'AUTS2', 'HAP1', 'TH', 'EN2', 'TAGLN', 'NDOR1', 'STAT3', 'OR4M1'}
#
#
# MP:0011957
# {'CAMKK2', 'MC3R', 'UBB', 'NMUR2', 'NPY1R', 'POMC', 'FASN', 'GALP', 'DBX1', 'OXT', 'MAGEL2', 'RCAN2', 'RXFP4', 'GPR39', 'DBH'}
# {'CAMKK2', 'POMC', 'MAGEL2', 'RCAN2', 'RXFP4', 'NMUR2', 'NPY1R', 'NPY5R', 'OXT', 'DBH', 'MC3R', 'GALP', 'DBX1', 'TH', 'FASN', 'UBB', 'GPR39'}
# Original  set()
# new  {'NPY5R', 'TH'}
#
#
# MP:0008819
# {'GTF2IRD1'}
# {'GTF2IRD1'}
# Original  set()
# new  set()
#
#
# MP:0011943
# {'INSR', 'HRH1'}
# {'INSR', 'HRH1'}
# Original  set()
# new  set()
#
#
# MP:0011944
# set()
# set()
# Original  set()
# new  set()
#
#
# MP:0011945
# {'GLP2R', 'RHBDF1', 'TAFA1'}
# {'GLP2R', 'RHBDF1', 'TAFA1'}
# Original  set()
# new  set()
#
#
# MP:0011946
# set()
# set()
# Original  set()
# new  set()
#
#
# MP:0011956
# set()
# set()
# Original  set()
# new  set()

# %%
new_genes = []
for node in nodes:
    new_genes += MPO_new.term_2_gene[node]
len(set(new_genes))
# Out:
# 776

# %%
mps = mgi_orig.MP.unique()
for _ in range(10):
    idx = rn.randint(0, len(mps))
    test = mps[idx]
    print(test)
    print("Original", mgi_orig.loc[mgi_orig.MP==test, "human_ortholog"].unique())
    print("New", mgi_new.loc[mgi_new.MP==test, "human_ortholog"].unique())
# Out:
# MP:0004813
# Original ['POU3F4' 'SLC30A4' 'NOX3' 'CYBA' 'AP3D1' 'ATP2B2' 'CDH23' 'SOBP' 'PCDH15'
#  'SPTBN4' 'USH1G' 'KCNE1' 'ESPN' 'MYO7A' 'TMIE' 'MYO6' 'HR' 'MBP' 'OTOP1'
#  'KCNA10' nan]
# New ['POU3F4' 'SLC30A4' 'NOX3' 'CYBA' 'AP3D1' 'ATP2B2' 'CDH23' 'SOBP' 'PCDH15'
#  'SPTBN4' 'USH1G' 'KCNE1' 'ESPN' 'MYO7A' 'TMIE' 'MYO6' 'HR' 'MBP' 'OTOP1'
#  'KCNA10' 'CAPZB']
# MP:0005175
# Original ['KIT' 'MITF' 'MCOLN3' 'PFAS' nan 'DOCK7' 'AEBP2' 'SOX10' 'RACK1']
# New ['KIT' 'MITF' 'MCOLN3' 'PFAS' 'DOCK7' 'KITLG' 'AEBP2' 'SOX10' 'RACK1']
# MP:0003905
# Original ['FBN1']
# New ['FBN1']
# MP:0002819
# Original ['DSPP' 'DMP1' 'COL1A1' 'MAP3K11' 'FAM20C' nan]
# New ['DSPP' 'DMP1' 'COL1A1' 'MAP3K11' 'FAM20C' 'SSUH2']
# MP:0013820
# Original ['CHD7' 'FOXG1' 'GAS2L2']
# New ['CHD7' 'FOXG1' 'GAS2L2']
# MP:0005659
# Original ['CREBBP' 'PTPN1' 'UCP1' 'HMGA2' 'TRPV1' 'CAV1' 'LIPE' 'ESRRA' 'PRKAR2B'
#  'KCNA3' 'FABP2' 'CNR1' 'PPARGC1A' 'SDC3' 'MCHR1' 'INPPL1' nan 'NPC1L1'
#  'FOXS1' 'GHSR' 'MAPK8' 'KCNJ11' 'TNF' 'DGAT1' 'CACNA1B' 'RANBP2' 'CBL'
#  'ADIPOR2' 'NOCT' 'ABCG1' 'PNLIP' 'SLC27A5' 'AEBP1' 'ARID5B' 'PNRC2'
#  'BCAT2' 'SNORD116' 'SOCS3' 'MBOAT4' 'PASK' 'CAMKK2' 'INPP5K' 'GPR50'
#  'AGRP' 'CIDEC' 'FABP5' 'GALP' 'PPARG' 'GDF3' 'NCOR1' 'ITPRID2' 'TBC1D1'
#  'MAPK13' 'PLIN1' 'FTO' 'MOGAT2' 'MARK2' 'CACNA1G' 'NMUR2' 'PRCP' 'MYD88'
#  'ATE1' 'AHSG' 'PRKAB1' 'APOE' 'AGTR2' 'MARK3' 'LCLAT1' 'COL1A1' 'AHNAK'
#  'CRTC3' 'AKT2' 'RMI1' 'DUSP1' 'NR2C2' 'RCAN2' 'SLC25A25' 'COL5A3' 'NCOA3'
#  'SGMS2' 'SLC13A5' 'HADH' 'MTM1' 'RLN3' 'GPR21' 'LRP6' 'AKT1' 'ACOT11'
#  'SIK3' 'MIR378A' 'MARK4' 'GATM' 'MFSD2A' 'SERTAD2' 'PLIN2' 'SLC16A1'
#  'GCGR' 'CRBN' 'PDE10A' 'ADCY3' 'SRA1' 'SRSF3' 'CERS6' 'CNOT3' 'ARNTL'
#  'IRX3' 'SLURP1' 'PTPN11' 'MAF1' 'ROCK2' 'GPAT3' 'G0S2' 'ARHGEF11' 'SIRT1'
#  'PLAAT3' 'MPZL3' 'C1QTNF1' 'LRRC8C' 'LNPEP' 'CYBB' 'TRAJ18' 'ABHD6'
#  'CHCHD4' 'CNOT6L' 'CNPY2' 'CYTH3' 'ARV1' 'PPP1R3G' 'A1CF' 'FBN1' 'LIPA'
#  'CLSTN3' 'ROBO4' 'LDLR' 'ABHD11' 'TMEM126B' 'HSPA12A' 'KMT2D' 'IMPACT'
#  'TCHP' 'ADIG' 'CRLS1' 'TRPC4AP' 'SLC25A24']
# New ['CREBBP' 'PTPN1' 'UCP1' 'HMGA2' 'TRPV1' 'CAV1' 'LIPE' 'ESRRA' 'PRKAR2B'
#  'KCNA3' 'FABP2' 'CNR1' 'PPARGC1A' 'SDC3' 'MCHR1' 'INPPL1' 'NPC1L1'
#  'FOXS1' 'GHSR' 'MAPK8' 'KCNJ11' 'TNF' 'DGAT1' 'CACNA1B' 'RANBP2' 'RGPD1'
#  'RGPD2' 'RGPD3' 'RGPD4' 'RGPD6' 'RGPD8' 'LDLR' 'CBL' 'ADIPOR2' 'NOCT'
#  'ABCG1' 'CEL' 'PNLIP' 'SLC27A5' 'AEBP1' 'ARID5B' 'PNRC2' 'BCAT2' 'SCD'
#  'SCD5' 'SOCS3' 'MBOAT4' 'PASK' 'LEP' 'CEBPA' 'CAMKK2' 'INPP5K' 'GPR50'
#  'SLC32A1' 'AGRP' 'CIDEC' 'FABP5' 'GALP' 'PPARG' 'GDF3' 'RPTOR' 'NCOR1'
#  'ITPRID2' 'TBC1D1' 'MAPK13' 'PLIN1' 'FTO' 'MOGAT2' 'MARK2' 'CACNA1G'
#  'NMUR2' 'PRCP' 'MYD88' 'ATE1' 'AHSG' 'PRKAB1' 'APOE' 'ITGB3' 'AGTR2'
#  'MARK3' 'LCLAT1' 'COL1A1' 'AHNAK' 'CRTC3' 'AKT2' 'RMI1' 'DUSP1' 'NR2C2'
#  'RCAN2' 'LRP1' 'SLC25A25' 'COL5A3' 'NCOA3' 'SGMS2' 'SLC13A5' 'HADH'
#  'PTPN2' 'MTM1' 'RLN3' 'GPR21' 'LRP6' 'AKT1' 'ACOT11' 'SIK3' 'MARK4'
#  'GATM' 'MFSD2A' 'SERTAD2' 'PLIN2' 'SLC16A1' 'GCGR' 'SAMD4A' 'CRBN'
#  'PDE10A' 'ADCY3' 'SRA1' 'SRSF3' 'CERS6' 'CNOT3' 'ARNTL' 'IRX3' 'SLURP1'
#  'PTPN11' 'MAF1' 'ROCK2' 'GPAT3' 'G0S2' 'ARHGEF11' 'SIRT1' 'CCAR2'
#  'PLAAT3' 'MPZL3' 'C1QTNF1' 'GNAS' 'LRRC8C' 'LNPEP' 'SAA2' 'SAA3P' 'EPRS1'
#  'BSCL2' 'CYBB' 'LYZ' 'GGCX' 'ABHD6' 'CHCHD4' 'CNOT6L' 'CNPY2' 'OR4M1'
#  'OR4M2' 'CYTH3' 'ARV1' 'PPP1R3G' 'A1CF' 'FBN1' 'LIPA' 'CLSTN3' 'ROBO4'
#  'FMO3' 'ABHD11' 'TMEM126B' 'HSPA12A' 'KMT2D' 'IMPACT' 'EIF2AK4' 'TCHP'
#  'ADIG' 'CRLS1' 'ZNF217' 'TRPC4AP' 'SLC25A24']
# MP:0009617
# Original ['SLC30A3' 'CTTNBP2']
# New ['SLC30A3' 'CTTNBP2']
# MP:0011759
# Original ['BMP4' 'FGFR2' 'HESX1' 'FGF10' 'HHEX' 'RPGRIP1L' 'NOG' 'PGAP1']
# New ['BMP4' 'FGFR2' 'HESX1' 'FGF10' 'HHEX' 'RPGRIP1L' 'NOG' 'PGAP1']
# MP:0011100
# Original [nan 'CFTR' 'EPOR' ... 'TXNL4A' 'UQCR10' 'UTP6']
# New ['CFTR' 'EPOR' 'TGFBR2' ... 'TXNL4A' 'UQCR10' 'UTP6']
# MP:0011520
# Original ['IL10' 'GPC3' nan]
# New ['IL10' 'GPC3']

# %%
len(mgi_orig)
# Out:
# 352807

# %% [markdown]
# ## Other

# %%
alleles = pd.read_csv("MGI_PhenotypicAllele.rpt", sep="\t", comment="#", header=None, names=["MGI Allele Accession ID", "Allele Symbol",
                                                                                             "Allele Name", "Allele Type","Allele Attribute","PubMed ID for original reference",
                                                                                             "MGI Marker Accession ID","Marker Symbol","Marker RefSeq ID",
                                                                                             "Marker Ensembl ID","High-level Mammalian Phenotype ID (comma-delimited)",
                                                                                             "Synonyms (|-delimited)","Marker Name"])

# %%
alleles.loc[5000:5002]
# Out:
#      MGI Allele Accession ID           Allele Symbol  \
# 5000             MGI:5554915  Bbs4<tm1b(EUCOMM)Hmgu>
# 5001             MGI:6509074  Bbs4<tm1c(EUCOMM)Hmgu>
# 5002             MGI:6509075  Bbs4<tm1d(EUCOMM)Hmgu>
#
#                                             Allele Name Allele Type  \
# 5000  targeted mutation 1b, Helmholtz Zentrum Muench...    Targeted
# 5001  targeted mutation 1c, Helmholtz Zentrum Muench...    Targeted
# 5002  targeted mutation 1d, Helmholtz Zentrum Muench...    Targeted
#
#             Allele Attribute  PubMed ID for original reference  \
# 5000  Reporter|Null/knockout                               NaN
# 5001       Conditional ready                        33426789.0
# 5002           Null/knockout                        33426789.0
#
#      MGI Marker Accession ID Marker Symbol Marker RefSeq ID  \
# 5000             MGI:2143311          Bbs4     XM_036154544
# 5001             MGI:2143311          Bbs4     XM_036154544
# 5002             MGI:2143311          Bbs4     XM_036154544
#
#        Marker Ensembl ID High-level Mammalian Phenotype ID (comma-delimited)  \
# 5000  ENSMUSG00000025235                              MP:0005386,MP:0010768
# 5001  ENSMUSG00000025235                                                NaN
# 5002  ENSMUSG00000025235                                                NaN
#
#      Synonyms (|-delimited)                      Marker Name
# 5000                    NaN  Bardet-Biedl syndrome 4 (human)
# 5001               Bbs4<FL>  Bardet-Biedl syndrome 4 (human)
# 5002              Bbss4<KO>  Bardet-Biedl syndrome 4 (human)

# %%
"Bbs4<tm1b(EUCOMM)Hmgu>" in mgi_orig["MGI_Allele_Accession_ID"]
# Out:
# False

# %%
mgi_new[mgi_new.gene_name=="Bbs4"]
# Out:
#           MGI_Allele_Accession_ID Allele symbol  \
# 47604   Bbs4<tm1Vcs>/Bbs4<tm1Vcs>  Bbs4<tm1Vcs>
# 47605   Bbs4<tm1Vcs>/Bbs4<tm1Vcs>  Bbs4<tm1Vcs>
# 47606   Bbs4<tm1Vcs>/Bbs4<tm1Vcs>  Bbs4<tm1Vcs>
# 47607   Bbs4<tm1Vcs>/Bbs4<tm1Vcs>  Bbs4<tm1Vcs>
# 47608   Bbs4<tm1Vcs>/Bbs4<tm1Vcs>  Bbs4<tm1Vcs>
# ...                           ...           ...
# 337470    Bbs4<Gt1Nk>/Bbs4<Gt1Nk>   Bbs4<Gt1Nk>
# 337471    Bbs4<Gt1Nk>/Bbs4<Gt1Nk>   Bbs4<Gt1Nk>
# 337472    Bbs4<Gt1Nk>/Bbs4<Gt1Nk>   Bbs4<Gt1Nk>
# 337473    Bbs4<Gt1Nk>/Bbs4<Gt1Nk>   Bbs4<Gt1Nk>
# 337474    Bbs4<Gt1Nk>/Bbs4<Gt1Nk>   Bbs4<Gt1Nk>
#
#                                          involves          MP      PMID  \
# 47604   involves: 129S1/Sv * 129X1/SvJ * C57BL/6J  MP:0001433  15173597
# 47605   involves: 129S1/Sv * 129X1/SvJ * C57BL/6J  MP:0001262  15173597
# 47606   involves: 129S1/Sv * 129X1/SvJ * C57BL/6J  MP:0001261  15173597
# 47607   involves: 129S1/Sv * 129X1/SvJ * C57BL/6J  MP:0001925  15173597
# 47608   involves: 129S1/Sv * 129X1/SvJ * C57BL/6J  MP:0001326  15173597
# ...                                           ...         ...       ...
# 337470                       B6.129S7-Bbs4<Gt1Nk>  MP:0009454  31479441
# 337471                       B6.129S7-Bbs4<Gt1Nk>  MP:0009456  31479441
# 337472                       B6.129S7-Bbs4<Gt1Nk>  MP:0020508  31479441
# 337473                       B6.129S7-Bbs4<Gt1Nk>  MP:0020511  31479441
# 337474                       B6.129S7-Bbs4<Gt1Nk>  MP:0030941  31479441
#
#        MGI_marker_accession_ID          MGI MGI Accession ID Marker Symbol  \
# 47604              MGI:2143311  MGI:2143311      MGI:2143311          Bbs4
# 47605              MGI:2143311  MGI:2143311      MGI:2143311          Bbs4
# 47606              MGI:2143311  MGI:2143311      MGI:2143311          Bbs4
# 47607              MGI:2143311  MGI:2143311      MGI:2143311          Bbs4
# 47608              MGI:2143311  MGI:2143311      MGI:2143311          Bbs4
# ...                        ...          ...              ...           ...
# 337470             MGI:2143311  MGI:2143311      MGI:2143311          Bbs4
# 337471             MGI:2143311  MGI:2143311      MGI:2143311          Bbs4
# 337472             MGI:2143311  MGI:2143311      MGI:2143311          Bbs4
# 337473             MGI:2143311  MGI:2143311      MGI:2143311          Bbs4
# 337474             MGI:2143311  MGI:2143311      MGI:2143311          Bbs4
#
#        human_ortholog gene_name
# 47604            BBS4      Bbs4
# 47605            BBS4      Bbs4
# 47606            BBS4      Bbs4
# 47607            BBS4      Bbs4
# 47608            BBS4      Bbs4
# ...               ...       ...
# 337470           BBS4      Bbs4
# 337471           BBS4      Bbs4
# 337472           BBS4      Bbs4
# 337473           BBS4      Bbs4
# 337474           BBS4      Bbs4
#
# [87 rows x 11 columns]

# %%
zz = pd.read_csv('MGI_GenePheno.rpt', sep="\t", names=["Allelic Composition","Allele Symbol(s)","Allele ID(s)",
                                                       "Genetic Background","Mammalian Phenotype ID","PubMed ID (pipe-delimited)","MGI Marker Accession ID (pipe-delimited)","MGI Genotype Accession ID (pipe-delimited)"])

# %%
zz.head()
# Out:
#        Allelic Composition Allele Symbol(s) Allele ID(s)  \
# 0  Rb1<tm1Tyj>/Rb1<tm1Tyj>      Rb1<tm1Tyj>  MGI:1857242
# 1  Rb1<tm1Tyj>/Rb1<tm1Tyj>      Rb1<tm1Tyj>  MGI:1857242
# 2  Rb1<tm1Tyj>/Rb1<tm1Tyj>      Rb1<tm1Tyj>  MGI:1857242
# 3  Rb1<tm1Tyj>/Rb1<tm1Tyj>      Rb1<tm1Tyj>  MGI:1857242
# 4  Rb1<tm1Tyj>/Rb1<tm1Tyj>      Rb1<tm1Tyj>  MGI:1857242
#
#       Genetic Background Mammalian Phenotype ID PubMed ID (pipe-delimited)  \
# 0  involves: 129S2/SvPas             MP:0000600                   12529408
# 1  involves: 129S2/SvPas             MP:0001716                   16449662
# 2  involves: 129S2/SvPas             MP:0001698                   16449662
# 3  involves: 129S2/SvPas             MP:0001092                   16449662
# 4  involves: 129S2/SvPas             MP:0000961                   16449662
#
#   MGI Marker Accession ID (pipe-delimited)  \
# 0                                MGI:97874
# 1                                MGI:97874
# 2                                MGI:97874
# 3                                MGI:97874
# 4                                MGI:97874
#
#   MGI Genotype Accession ID (pipe-delimited)
# 0                                MGI:2166359
# 1                                MGI:2166359
# 2                                MGI:2166359
# 3                                MGI:2166359
# 4                                MGI:2166359

# %%
zz[zz["Allele ID(s)"] == "MGI:5554915"]
# Out:
#                                   Allelic Composition  \
# 195340                 Bbs4<tm1b(EUCOMM)Hmgu>/Bbs4<+>
# 195341                 Bbs4<tm1b(EUCOMM)Hmgu>/Bbs4<+>
# 195342  Bbs4<tm1b(EUCOMM)Hmgu>/Bbs4<tm1b(EUCOMM)Hmgu>
#
#                       Allele Symbol(s) Allele ID(s)  \
# 195340  Bbs4<+>|Bbs4<tm1b(EUCOMM)Hmgu>  MGI:5554915
# 195341  Bbs4<+>|Bbs4<tm1b(EUCOMM)Hmgu>  MGI:5554915
# 195342          Bbs4<tm1b(EUCOMM)Hmgu>  MGI:5554915
#
#                       Genetic Background Mammalian Phenotype ID  \
# 195340  B6N(Cg)-Bbs4<tm1b(EUCOMM)Hmgu>/J             MP:0001417
# 195341  B6N(Cg)-Bbs4<tm1b(EUCOMM)Hmgu>/J             MP:0020870
# 195342  B6N(Cg)-Bbs4<tm1b(EUCOMM)Hmgu>/J             MP:0011110
#
#        PubMed ID (pipe-delimited) MGI Marker Accession ID (pipe-delimited)  \
# 195340                        NaN                              MGI:2143311
# 195341                        NaN                              MGI:2143311
# 195342                        NaN                              MGI:2143311
#
#        MGI Genotype Accession ID (pipe-delimited)
# 195340                                MGI:5763838
# 195341                                MGI:5763838
# 195342                                MGI:5763839

# %%
zz[zz["MGI Marker Accession ID (pipe-delimited)"]=="MGI:2143311"]
# Out:
#               Allelic Composition Allele Symbol(s) Allele ID(s)  \
# 40066   Bbs4<tm1Vcs>/Bbs4<tm1Vcs>     Bbs4<tm1Vcs>  MGI:3045473
# 40067   Bbs4<tm1Vcs>/Bbs4<tm1Vcs>     Bbs4<tm1Vcs>  MGI:3045473
# 40068   Bbs4<tm1Vcs>/Bbs4<tm1Vcs>     Bbs4<tm1Vcs>  MGI:3045473
# 40069   Bbs4<tm1Vcs>/Bbs4<tm1Vcs>     Bbs4<tm1Vcs>  MGI:3045473
# 40070   Bbs4<tm1Vcs>/Bbs4<tm1Vcs>     Bbs4<tm1Vcs>  MGI:3045473
# ...                           ...              ...          ...
# 229917    Bbs4<Gt1Nk>/Bbs4<Gt1Nk>      Bbs4<Gt1Nk>  MGI:3055492
# 229918    Bbs4<Gt1Nk>/Bbs4<Gt1Nk>      Bbs4<Gt1Nk>  MGI:3055492
# 229919    Bbs4<Gt1Nk>/Bbs4<Gt1Nk>      Bbs4<Gt1Nk>  MGI:3055492
# 229920    Bbs4<Gt1Nk>/Bbs4<Gt1Nk>      Bbs4<Gt1Nk>  MGI:3055492
# 229921    Bbs4<Gt1Nk>/Bbs4<Gt1Nk>      Bbs4<Gt1Nk>  MGI:3055492
#
#                                Genetic Background Mammalian Phenotype ID  \
# 40066   involves: 129S1/Sv * 129X1/SvJ * C57BL/6J             MP:0001433
# 40067   involves: 129S1/Sv * 129X1/SvJ * C57BL/6J             MP:0001262
# 40068   involves: 129S1/Sv * 129X1/SvJ * C57BL/6J             MP:0001261
# 40069   involves: 129S1/Sv * 129X1/SvJ * C57BL/6J             MP:0001925
# 40070   involves: 129S1/Sv * 129X1/SvJ * C57BL/6J             MP:0001326
# ...                                           ...                    ...
# 229917                       B6.129S7-Bbs4<Gt1Nk>             MP:0009454
# 229918                       B6.129S7-Bbs4<Gt1Nk>             MP:0009456
# 229919                       B6.129S7-Bbs4<Gt1Nk>             MP:0020508
# 229920                       B6.129S7-Bbs4<Gt1Nk>             MP:0020511
# 229921                       B6.129S7-Bbs4<Gt1Nk>             MP:0030941
#
#        PubMed ID (pipe-delimited) MGI Marker Accession ID (pipe-delimited)  \
# 40066                    15173597                              MGI:2143311
# 40067                    15173597                              MGI:2143311
# 40068                    15173597                              MGI:2143311
# 40069                    15173597                              MGI:2143311
# 40070                    15173597                              MGI:2143311
# ...                           ...                                      ...
# 229917                   31479441                              MGI:2143311
# 229918                   31479441                              MGI:2143311
# 229919                   31479441                              MGI:2143311
# 229920                   31479441                              MGI:2143311
# 229921                   31479441                              MGI:2143311
#
#        MGI Genotype Accession ID (pipe-delimited)
# 40066                                 MGI:3045547
# 40067                                 MGI:3045547
# 40068                                 MGI:3045547
# 40069                                 MGI:3045547
# 40070                                 MGI:3045547
# ...                                           ...
# 229917                                MGI:6370045
# 229918                                MGI:6370045
# 229919                                MGI:6370045
# 229920                                MGI:6370045
# 229921                                MGI:6370045
#
# [86 rows x 8 columns]

# %%
new_map = pd.read_csv('MGI_GenePheno.rpt', sep="\t", usecols=[2, 4, 6],
                  names=["Allele_ID","MP","MGI"])
new_map.head()
# Out:
#      Allele_ID          MP        MGI
# 0  MGI:1857242  MP:0000600  MGI:97874
# 1  MGI:1857242  MP:0001716  MGI:97874
# 2  MGI:1857242  MP:0001698  MGI:97874
# 3  MGI:1857242  MP:0001092  MGI:97874
# 4  MGI:1857242  MP:0000961  MGI:97874

# %%
new_map.loc["MGI"] = new_map.MGI.apply(lambda x: x.split("|"))
new_map = new_map.explode("MGI")
# Out:
#      Allele_ID          MP        MGI
# 0  MGI:1857242  MP:0000600  MGI:97874
# 1  MGI:1857242  MP:0001716  MGI:97874
# 2  MGI:1857242  MP:0001698  MGI:97874
# 3  MGI:1857242  MP:0001092  MGI:97874
# 4  MGI:1857242  MP:0000961  MGI:97874

# %%
xx = pd.read_csv("HMD_HumanPhenotype.rpt", sep="\t", usecols=[0,2,3], names=["symbol", "gene_name", "MGI"])
xx.head()
# Out:
#   symbol gene_name          MGI
# 0   A1BG      A1bg  MGI:2152878
# 1   A1CF      A1cf  MGI:1917115
# 2    A2M       A2m  MGI:2449119
# 3  A2ML1      Mug1    MGI:99837
# 4  A2ML1      Mug2    MGI:99836

# %%
new_map.head()
# Out:
#      Allele_ID          MP        MGI
# 0  MGI:1857242  MP:0000600  MGI:97874
# 1  MGI:1857242  MP:0001716  MGI:97874
# 2  MGI:1857242  MP:0001698  MGI:97874
# 3  MGI:1857242  MP:0001092  MGI:97874
# 4  MGI:1857242  MP:0000961  MGI:97874

# %%
mapping = new_map.merge(xx, on="MGI", how="outer")

# %%
mapping
# Out:
#           Allele_ID          MP          MGI  symbol gene_name
# 0       MGI:1857242  MP:0000600    MGI:97874     RB1       Rb1
# 1       MGI:1857242  MP:0001716    MGI:97874     RB1       Rb1
# 2       MGI:1857242  MP:0001698    MGI:97874     RB1       Rb1
# 3       MGI:1857242  MP:0001092    MGI:97874     RB1       Rb1
# 4       MGI:1857242  MP:0000961    MGI:97874     RB1       Rb1
# ...             ...         ...          ...     ...       ...
# 270189          NaN         NaN  MGI:3694898    ZXDA      Zxdb
# 270190          NaN         NaN  MGI:3694898    ZXDB      Zxdb
# 270191          NaN         NaN  MGI:1933108    ZXDC      Zxdc
# 270192          NaN         NaN  MGI:2446208  ZYG11A    Zyg11a
# 270193          NaN         NaN  MGI:1920453    ZZZ3      Zzz3
#
# [270194 rows x 5 columns]

# %%
mps = mgi_orig.MP.unique()
for _ in range(10):
    idx = rn.randint(0, len(mps))
    test = mps[idx]
    print(test)
    print("Original", mgi_orig.loc[mgi_orig.MP==test, "human_ortholog"].unique())
    print("New", mapping.loc[mapping.MP==test, "symbol"].unique())
# Out:
# MP:0000073
# Original ['CTNNB1' 'PTPN11']
# New []
# MP:0003903
# Original ['GABPA' 'SEPTIN7']
# New []
# MP:0010015
# Original ['POU4F3' 'CAPZB' 'MYO6']
# New ['MYO6' 'POU4F3']
# MP:0008070
# Original ['FOXN1' nan 'CBFB' 'IKZF1' 'ITPKB' 'ZAP70' 'XRCC5' 'TCF12' 'CD3E' 'KLF2'
#  'RAG2' 'PRKDC' 'PRF1' 'IL2RG' 'BCL11B' 'LAT' 'PTPRC' 'FYN' 'RAG1' 'ZBTB1'
#  'DCLRE1C' 'COL7A1']
# New ['FOXN1' 'LAT' 'RAG1' nan 'IKZF1' 'CD3E' 'PRKDC' 'BCL11B' 'DCLRE1C'
#  'ITPKB' 'PTPRC' 'COL7A1' 'TCF12' 'ZAP70' 'XRCC5']
# MP:0014168
# Original ['DOCK7']
# New ['DOCK7']
# MP:0009325
# Original [nan 'BRWD1' 'CSF1' 'PFDN5' 'BEST1' 'VPS13B' 'KCNG4']
# New ['CD59' 'QKI' 'BRWD1' 'EPHB6' 'CSF1' 'BEST1' 'PFDN5' 'TRPV6' 'KCNG4'
#  'VPS13B']
# MP:0008365
# Original ['NPC1' 'SLC6A3' 'EGR1' 'PROP1' 'PITX2' 'POU1F1' 'LIN9' 'CDK4' 'LHX3']
# New ['PITX2' 'CDK4' 'NPC1' 'SLC6A3' 'EGR1' 'PROP1' 'LHX3' 'POU1F1']
# MP:0010919
# Original ['HES1' 'FBN1' 'NEUROD1']
# New ['HES1' 'NEUROD1' 'FBN1']
# MP:0030016
# Original ['PIK3R1' 'PRKCA' 'NPY1R' nan 'TLR2' 'SLC2A4' 'FABP5' 'LEP' 'PPARG'
#  'ITPRID2' 'E2F1' 'MARK2' 'TRIP10' 'TBC1D4' 'ACOT11' 'BBS12' 'GATM'
#  'PIKFYVE' 'PTPN11' 'ANK2' 'CRTC2' 'NR1D1' 'FOXA3' 'ABHD6' 'BCL6' 'EHD2']
# New ['PIK3R1' 'PPARG' 'PTPN11' 'TLR2' 'ANK2' 'MARK2' 'PRKCA' 'NPY1R' 'INS'
#  'INS-IGF2' 'FOXA3' 'FABP5' 'E2F1' 'NR1D1' 'ITPRID2' 'CRTC2' 'TRIP10'
#  'TBC1D4' 'ACOT11' 'BBS12' 'GATM' 'ABHD6' 'EHD2']
# MP:0001198
# Original [nan 'COL3A1' 'SLC27A4' 'TGM1' 'DGAT2' 'FST' 'FOXP3' 'FBN1' 'CHUK' 'KIT'
#  'IRF6' 'ABCA12' 'PDGFRA' 'ITGB1' 'CEBPA' 'RYR1' 'KDF1' 'SNAP29' 'PNPLA1']
# New ['RYR1' 'FOXP3' 'COL3A1' 'SLC27A4' 'TGM1' 'DGAT2' 'FST' 'CHUK' 'FBN1'
#  'ABCA12' 'IRF6' 'KDF1' 'PNPLA1' 'SNAP29']

# %%
xx[xx.MGI=="MGI:88276"]
# Out:
#       symbol gene_name        MGI
# 4181  CTNNB1    Ctnnb1  MGI:88276

# %%
new_map[new_map.MGI=="MGI:95610"].sort_values(by="MP").MP.values
# Out:
# array(['MP:0000438', 'MP:0000706', 'MP:0000715', 'MP:0001293',
#        'MP:0002102', 'MP:0003743', 'MP:0004200', 'MP:0011091',
#        'MP:0011092', 'MP:0011099', 'MP:0011100'], dtype=object)

# %%
mgi_new[mgi_new["MP"]=="MP:0003903"]
# Out:
#                 MGI_Allele_Accession_ID    Allele symbol  \
# 124231    Gabpa<tm1Agro>/Gabpa<tm1Agro>   Gabpa<tm1Agro>
# 275030  Septin7<tm1Mgl>/Septin7<tm1Mgl>  Septin7<tm1Mgl>
#
#                                       involves          MP      PMID  \
# 124231                           involves: 129  MP:0003903  17277770
# 275030  involves: 129P2/OlaHsd * C3H * C57BL/6  MP:0003903  25122120
#
#        MGI_marker_accession_ID          MGI MGI Accession ID Marker Symbol  \
# 124231               MGI:95610    MGI:95610        MGI:95610         Gabpa
# 275030             MGI:1335094  MGI:1335094      MGI:1335094       Septin7
#
#        human_ortholog gene_name
# 124231          GABPA     Gabpa
# 275030        SEPTIN7   Septin7
